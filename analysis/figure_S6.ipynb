# %%
import os
import pdb
import h5py
import pickle
from collections import defaultdict

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.stats import pearsonr, spearmanr
from tqdm import tqdm

# %% [markdown]
# # Config

# %%
geuvadis_eQTL_dir = "/clusterfs/nilah/Geuvadis/E-GEUV-1/analysis_results"
geuvadis_genotypes_dir = "/clusterfs/nilah/Geuvadis/E-GEUV-1/genotypes/"
data_dir = "/clusterfs/nilah/ruchir/src/finetuning-enformer/finetuning/data/h5_bins_384_chrom_split/"
enformer_data_dir = "/global/scratch/users/aniketh/enformer_data/"
root_save_dir = "/global/scratch/users/aniketh/finetune-enformer/"
code_dir = "/global/home/users/aniketh/finetuning-enformer/"
fasta_path = "/clusterfs/nilah/aniketh/hg19/hg19.fa"

models_dir = os.path.join(root_save_dir, "saved_models")
test_preds_dir = os.path.join(root_save_dir, "test_preds_final")
rest_unseen_preds_dir = os.path.join(root_save_dir, "rest_unseen_preds_final")
ISM_preds_dir = os.path.join(root_save_dir, "ISM")

train_h5_path = os.path.join(data_dir, "train.h5")
val_h5_path = os.path.join(data_dir, "val.h5")
test_h5_path = os.path.join(data_dir, "test.h5")
rest_unseen_h5_path = os.path.join(data_dir, "rest_unseen.h5")

GEUVADIS_COUNTS_PATH = "../process_geuvadis_data/log_tpm/corrected_log_tpm.annot.csv.gz"
BASELINE_PREDS_PATH = (
    "../baseline/baseline_enformer.384_bins.rc.csv"
)
FUSION_PREDS_DIR = "../fusion/preds"
FUSION_SCALING_PREDS_DIR = "../fusion/preds_scaling/"

all_main_run_names={
#     "classification": "NCCL_P2P_DISABLE=1 python finetuning/train_pairwise_classification_parallel_h5_dataset_dynamic_sampling_dataset.py {train_h5_path} {val_h5_path} {run_name} {models_dir} --batch_size 1 --lr 0.0001 --weight_decay 0.001 --data_seed {data_seed} --resume_from_checkpoint",
    "regression": "NCCL_P2P_DISABLE=1 python finetuning/train_pairwise_regression_parallel_h5_dataset.py {train_h5_path} {val_h5_path} {run_name} {models_dir} --batch_size 1 --lr 0.0001 --weight_decay 0.001 --use_scheduler --warmup_steps 1000 --data_seed {data_seed} --resume_from_checkpoint",
#     "single_regression_counts": "NCCL_P2P_DISABLE=1 python finetuning/train_single_counts_parallel_h5_dataset.py {train_h5_path} {val_h5_path} {run_name} {models_dir} --batch_size 2 --lr 0.0001 --weight_decay 0.001 --use_scheduler --warmup_steps 1000 --data_seed {data_seed} --resume_from_checkpoint",
# #     "single_regression": "NCCL_P2P_DISABLE=1 python finetuning/train_single_parallel_h5_dataset.py {train_h5_path} {val_h5_path} {run_name} {models_dir} --batch_size 2 --lr 0.0001 --weight_decay 0.001 --use_scheduler --warmup_steps 1000 --data_seed {data_seed} --resume_from_checkpoint", ###DOEST PERFORM WELL, NOT USED
#     "joint_classification": "NCCL_P2P_DISABLE=1 python finetuning/train_pairwise_classification_with_enformer_data_parallel_h5_dynamic_sampling_dataset.py {train_h5_path} {val_h5_path} {enformer_data_dir} {run_name} {models_dir} --batch_size 1 --lr 0.0005 --weight_decay 0.005 --use_scheduler --warmup_steps 1000 --data_seed {data_seed} --resume_from_checkpoint",
#     "joint_regression": "NCCL_P2P_DISABLE=1 python finetuning/train_pairwise_regression_with_enformer_data_parallel_h5_dynamic_sampling_dataset.py {train_h5_path} {val_h5_path} {enformer_data_dir} {run_name} {models_dir} --batch_size 1 --lr 0.0005 --weight_decay 0.005 --use_scheduler --warmup_steps 1000 --data_seed {data_seed} --resume_from_checkpoint",
#     "joint_regression_with_Malinois_MPRA": "NCCL_P2P_DISABLE=1 python finetuning/train_pairwise_regression_with_MPRA_data_parallel_h5_dynamic_sampling_dataset.py {train_h5_path} {val_h5_path} {malinois_data_path} {run_name} {models_dir} --batch_size 1 --lr 0.0001 --weight_decay 0.001 --use_scheduler --warmup_steps 1000 --data_seed {data_seed} --resume_from_checkpoint",
    "baseline": "",
}
all_seeds = [42, 97, 7]
train_h5 = h5py.File(train_h5_path, "r")
context_size = train_h5["seqs"][0].shape[1]
train_h5.close()

# %%
ALL_PREDS_PATHS = {}
ALL_REST_UNSEEN_PREDS_PATHS = {}

# MAIN TEST RUNS
for run in all_main_run_names:
    if run == "baseline":
        ALL_PREDS_PATHS[run] = os.path.join(test_preds_dir, run)
        ALL_REST_UNSEEN_PREDS_PATHS[run] = os.path.join(rest_unseen_preds_dir, run)
    else:
        for i, seed in enumerate(all_seeds):
            train_cmd_template = all_main_run_names[run]
            lr_used_during_training = train_cmd_template.split("--lr ")[-1].split(" ")[0]
            wd_used_during_training = train_cmd_template.split("--weight_decay ")[-1].split(" ")[0]
            rcprob_used_during_training = 0.5
            rsmax_used_during_training = 3
                
            model_name = f"{run}_data_seed_{seed}_lr_{lr_used_during_training}_wd_{wd_used_during_training}_rcprob_{rcprob_used_during_training}_rsmax_{rsmax_used_during_training}"
            ALL_PREDS_PATHS[model_name] = os.path.join(test_preds_dir, model_name)
            ALL_REST_UNSEEN_PREDS_PATHS[model_name] = os.path.join(rest_unseen_preds_dir, model_name)

test_h5 = h5py.File(test_h5_path, "r")
rest_unseen_h5 = h5py.File(rest_unseen_h5_path, "r")

# %% [markdown]
# # Read test set predictions and compute correlations

# %%
def load_geuvadis_data() -> pd.DataFrame:
    counts_df = pd.read_csv(GEUVADIS_COUNTS_PATH, index_col=0)
    counts_df = counts_df.reset_index().set_index("our_gene_name")
    return counts_df


def load_finetuned_preds(PREDS_PATH, h5_obj):
    """
    Returns a dictionary of dictionaries, where the outer keys are the genes
    and the inner keys are the samples. The values are the predictions.
    """
    preds_by_gene = defaultdict(dict)
    ancestries_by_gene = defaultdict(dict)
    data = np.load(os.path.join(PREDS_PATH, "test_preds.npz"))

    preds, genes, samples = data["preds"], data["genes"], data["samples"]
    ancestries = h5_obj["ancestries"]
    for (pred, gene, sample, ancestry) in zip(preds, genes, samples, ancestries):
        preds_by_gene[gene][sample] = pred
        ancestries_by_gene[gene][sample] = ancestry.decode("utf-8")
    return preds_by_gene, ancestries_by_gene


def get_finetuned_corrs(finetuned_preds, geuvadis_df):
    corrs = {}
    for g in finetuned_preds:
        assert g in geuvadis_df.index
        samples = list(finetuned_preds[g].keys())
        gene_preds = [finetuned_preds[g][s] for s in samples]
        gene_counts = geuvadis_df.loc[g, samples].values.astype("float32")
        assert np.isnan(gene_preds).sum() == 0
        assert np.isnan(gene_counts).sum() == 0
        corrs[g] = pearsonr(gene_preds, gene_counts)[0]
        
        try:
            assert np.isnan(corrs[g]).sum() == 0
        except:
            print(f"Gene {g} has invalid predictions/counts and thus has a nan pearsonR")
            corrs[g] = 0
            
    return corrs


def compare_to_geuvadis_counts(finetuned_preds, geuvadis_df, gene, ax):
    samples = list(finetuned_preds[gene].keys())
    gene_preds = [finetuned_preds[gene][s] for s in samples]
    gene_counts = geuvadis_df.loc[gene, samples].values
    ax.scatter(gene_counts, gene_preds)
    ax.set(
        xlabel="Geuvadis counts",
        ylabel="finetuned predictions",
        title=f"Correlation: {pearsonr(gene_preds, gene_counts)[0]:.3f}",
    )


def compare_to_baseline_counts(finetuned_preds, baseline_df, gene, ax):
    samples = list(finetuned_preds[gene].keys())
    baseline_preds = baseline_df[gene][samples].values
    finetuned_preds = [finetuned_preds[gene][s] for s in samples]
    ax.scatter(baseline_preds, finetuned_preds)
    ax.set(
        xlabel="baseline predictions",
        ylabel="finetuned predictions",
        title=f"Correlation: {pearsonr(baseline_preds, finetuned_preds)[0]:.3f}",
    )


def load_other_model_preds_df(preds_df_path):
    preds_df = pd.read_csv(preds_df_path, index_col=0).T
    return preds_df


def get_other_model_corrs(preds_df, geuvadis_df, finetuned_preds):
    corrs = {}
    for g in finetuned_preds:
        if g not in preds_df.columns:
            print(f"Gene {g} has no predictions/counts and thus has a nan PearsonR")
            corrs[g] = 0
            continue
        
        assert g in geuvadis_df.index
        samples = list(finetuned_preds[g].keys())

        gene_preds = preds_df[g][samples].values
        gene_counts = geuvadis_df.loc[g, samples].values
        corrs[g] = pearsonr(gene_preds, gene_counts)[0]
        
        try:
            assert np.isnan(corrs[g]).sum() == 0
        except:
            print(f"Gene {g} has invalid predictions/counts and thus has a nan PearsonR")
            corrs[g] = 0
            
    return corrs


def compare_finetuned_to_baseline_perf(
    finetuned_corrs, baseline_corrs, finetuned_preds, ancestries_by_gene, abs_corrs: bool = False
):
    genes = list(finetuned_corrs.keys())
    finetuned_corrs_l = [finetuned_corrs[g] for g in genes]
    baseline_corrs_l = [baseline_corrs[g] for g in genes]
    
    gene_class = []
    for g in genes:
        temp = np.array([ancestries_by_gene[g][key] for key in ancestries_by_gene[g]])
        if (temp != "Yoruba").sum() == 0:
            gene_class.append("yri_split")
        elif len(finetuned_preds[g]) <= 77:
            gene_class.append("random_split")
        else:
            gene_class.append("unseen")
    
    df = pd.DataFrame(
        {
            "gene": genes,
            "finetuned Pearson": np.abs(finetuned_corrs_l) 
            if abs_corrs 
            else finetuned_corrs_l,
            "baseline Pearson": np.abs(baseline_corrs_l)
            if abs_corrs
            else baseline_corrs_l,
            "gene_class": gene_class,
        }
    )

    ax = sns.scatterplot(
        data=df,
        x="baseline Pearson",
        y="finetuned Pearson",
        hue="gene_class",
    )
    ax.set_ylabel("|finetuned Pearson|" if abs_corrs else "finetuned Pearson")
    ax.set_xlabel("|baseline Pearson|" if abs_corrs else "baseline Pearson")
    lims = [
        np.min([ax.get_xlim(), ax.get_ylim()]),  # min of both axes
        np.max([ax.get_xlim(), ax.get_ylim()]),  # max of both axes
    ]
    ax.set(aspect="equal", xlim=lims, ylim=lims)
    
    ax.axhline(
        df[df["gene_class"] == "random_split"]["finetuned Pearson"].mean(),
        color="blue",
        ls="--",
        label="random_split"
    )
    ax.axvline(
        df[df["gene_class"] == "random_split"]["baseline Pearson"].mean(),
        color="blue",
        ls="--",
        label="random_split"
    )

    ax.axhline(
        df[df["gene_class"] == "yri_split"]["finetuned Pearson"].mean(),
        color="orange",
        ls="--",
        label="yri_split"
    )
    ax.axvline(
        df[df["gene_class"] == "yri_split"]["baseline Pearson"].mean(),
        color="orange",
        ls="--",
        label="yri_split"
    )
    
    ax.axhline(
        df[df["gene_class"] == "unseen"]["finetuned Pearson"].mean(),
        color="green",
        ls="--",
        label="unseen"
    )
    ax.axvline(
        df[df["gene_class"] == "unseen"]["baseline Pearson"].mean(),
        color="green",
        ls="--",
        label="unseen"
    )
    
    summary = {}
    
    for split in ["random_split", "yri_split", "unseen"]:
        print(f"Split {split}, n_samples = {(df['gene_class'] == split).sum()}")
        print(f"Baseline PearsonR = {df[df['gene_class'] == split]['baseline Pearson'].mean()}")
        print(f"Finetuned PearsonR = {df[df['gene_class'] == split]['finetuned Pearson'].mean()}")
        print()
        
        summary["Baseline " + split] = df[df['gene_class'] == split]['baseline Pearson'].mean()
        summary["Finetuned " + split] = df[df['gene_class'] == split]['finetuned Pearson'].mean()

    plt.show()
    return summary


def summarize_perf(
    corrs, preds, ancestries_by_gene, abs_corrs: bool = False
):
    genes = list(corrs.keys())
    corrs_l = [corrs[g] for g in genes]
    
    gene_class = []
    for g in genes:
        temp = np.array([ancestries_by_gene[g][key] for key in ancestries_by_gene[g]])
        if (temp != "Yoruba").sum() == 0:
            gene_class.append("yri_split")
        elif len(preds[g]) <= 77:
            gene_class.append("random_split")
        else:
            gene_class.append("unseen")
    
    df = pd.DataFrame(
        {
            "gene": genes,
            "Pearson": corrs_l,
            "|Pearson|": np.abs(corrs_l),
            "gene_class": gene_class,
        }
    )
    
    summary = {}
    
    for split in ["random_split", "yri_split", "unseen"]:
        print(f"Split {split}, n_samples = {(df['gene_class'] == split).sum()}")
        print(f"PearsonR = {df[df['gene_class'] == split]['Pearson'].mean()}")
        print(f"|PearsonR| = {df[df['gene_class'] == split]['|Pearson|'].mean()}")
        print()
        
        summary[split + 'Pearson'] = df[df['gene_class'] == split]['Pearson'].mean()
        summary[split + '|Pearson|'] = df[df['gene_class'] == split]['|Pearson|'].mean()
        
    return summary

# %%
geuvadis_df = load_geuvadis_data()
baseline_df = load_other_model_preds_df(BASELINE_PREDS_PATH)
fusion_dfs = {}
for model_csv in os.listdir(FUSION_PREDS_DIR):
    fusion_dfs[model_csv.split(".")[0]] = load_other_model_preds_df(os.path.join(FUSION_PREDS_DIR, model_csv))

# %%
fusion_dfs.keys()
# Out:
# dict_keys(['top1', 'blup', 'bslmm', 'enet', 'lasso'])

# %%
if not os.path.exists("gene_perf.csv"):
    gene_perf = {}
    
    # get baseline corrs
    PREDS_PATH = ALL_PREDS_PATHS["baseline"]
    baseline_preds, ancestries_by_gene = load_finetuned_preds(PREDS_PATH, test_h5)
    baseline_corrs = get_finetuned_corrs(baseline_preds, geuvadis_df)
    
    REST_UNSEEN_PREDS_PATH = ALL_REST_UNSEEN_PREDS_PATHS["baseline"]
    rest_unseen_baseline_preds, rest_unseen_ancestries_by_gene = load_finetuned_preds(REST_UNSEEN_PREDS_PATH, rest_unseen_h5)
    rest_unseen_baseline_corrs = get_finetuned_corrs(rest_unseen_baseline_preds, geuvadis_df)
    
    baseline_corrs.update(rest_unseen_baseline_corrs)
    baseline_preds.update(rest_unseen_baseline_preds)
    ancestries_by_gene.update(rest_unseen_ancestries_by_gene)
    
    genes = list(baseline_corrs.keys())
    
    gene_class = []
    for g in genes:
        temp = np.array([ancestries_by_gene[g][key] for key in ancestries_by_gene[g]])
        if (temp != "Yoruba").sum() == 0:
            gene_class.append("yri_split")
        elif len(baseline_preds[g]) <= 77:
            gene_class.append("random_split")
        else:
            gene_class.append("unseen")
            
    baseline_corrs_l = [baseline_corrs[g] for g in genes]
    
    gene_perf["gene"] = genes
    gene_perf["gene_class"] = gene_class
    gene_perf["baseline_Pearson"] = baseline_corrs_l
    
    # get predixcan corrs
    predixcan_corrs = get_other_model_corrs(fusion_dfs["enet"], geuvadis_df, baseline_preds)
    predixcan_corrs_l = [predixcan_corrs[g] for g in genes]
    gene_perf["predixcan_Pearson"] = predixcan_corrs_l
    
    gene_perf = pd.DataFrame(gene_perf)
    
    # get pairwise regression corrs across all seeds
    for model in ALL_PREDS_PATHS:
        if model == "baseline":
            continue
            
        PREDS_PATH = ALL_PREDS_PATHS[model]
        finetuned_preds, ancestries_by_gene = load_finetuned_preds(PREDS_PATH, test_h5)
        finetuned_corrs = get_finetuned_corrs(finetuned_preds, geuvadis_df)
    
        REST_UNSEEN_PREDS_PATH = ALL_REST_UNSEEN_PREDS_PATHS[model]
        rest_unseen_finetuned_preds, rest_unseen_ancestries_by_gene = load_finetuned_preds(REST_UNSEEN_PREDS_PATH, rest_unseen_h5)
        rest_unseen_finetuned_corrs = get_finetuned_corrs(rest_unseen_finetuned_preds, geuvadis_df)
    
        finetuned_corrs.update(rest_unseen_finetuned_corrs)
        finetuned_preds.update(rest_unseen_finetuned_preds)
        ancestries_by_gene.update(rest_unseen_ancestries_by_gene)
    
        genes = list(finetuned_corrs.keys())
        finetuned_corrs_l = [finetuned_corrs[g] for g in genes]
        
        df = pd.DataFrame(
            {
                "gene": genes,
                f"finetuned_Pearson_{model}": finetuned_corrs_l            
            }
        )
    
        gene_perf = gene_perf.merge(df, on="gene", how="inner", validate="one_to_one")
    
    # compute mean pearson across seeds
    gene_perf["Mean Pearson Correlation"] = 0
    for model in ALL_PREDS_PATHS:
        if model == "baseline":
            continue
        gene_perf["Mean Pearson Correlation"] += gene_perf[f"finetuned_Pearson_{model}"]
    gene_perf["Mean Pearson Correlation"] /= len(ALL_PREDS_PATHS)
    
    gene_perf.to_csv("gene_perf.csv", index=False)
else:
    gene_perf = pd.read_csv("gene_perf.csv")
# Out:
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# Gene golga6l9 has invalid predictions/counts and thus has a nan pearsonR
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# Gene ensg00000184779 has invalid predictions/counts and thus has a nan pearsonR
# Gene ensg00000196648 has invalid predictions/counts and thus has a nan pearsonR
# Gene ensg00000197701 has invalid predictions/counts and thus has a nan pearsonR
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# Gene nprl3 has invalid predictions/counts and thus has a nan pearsonR
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# Gene polr3k has invalid predictions/counts and thus has a nan pearsonR
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# Gene snrnp25 has invalid predictions/counts and thus has a nan pearsonR
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# Gene znf718 has invalid predictions/counts and thus has a nan pearsonR
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# Gene cd58 has invalid predictions/counts and thus has a nan PearsonR
# Gene yif1a has invalid predictions/counts and thus has a nan PearsonR
# Gene nbl1 has invalid predictions/counts and thus has a nan PearsonR
# Gene alox15b has invalid predictions/counts and thus has a nan PearsonR
# Gene ubqlnl has invalid predictions/counts and thus has a nan PearsonR
# Gene eif3i has invalid predictions/counts and thus has a nan PearsonR
# Gene p2rx1 has invalid predictions/counts and thus has a nan PearsonR
# Gene dxo has invalid predictions/counts and thus has a nan PearsonR
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# Gene dmac2 has invalid predictions/counts and thus has a nan PearsonR
# Gene dus1l has invalid predictions/counts and thus has a nan PearsonR
# Gene dnah17 has invalid predictions/counts and thus has a nan PearsonR
# Gene itgae has invalid predictions/counts and thus has a nan PearsonR
# Gene ensg00000145965 has invalid predictions/counts and thus has a nan PearsonR
# Gene slc39a1 has invalid predictions/counts and thus has a nan PearsonR
# Gene lilrb2 has invalid predictions/counts and thus has a nan PearsonR
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# Gene arhgap24 has invalid predictions/counts and thus has a nan PearsonR
# Gene pigo has invalid predictions/counts and thus has a nan PearsonR
# Gene ensg00000204807 has invalid predictions/counts and thus has a nan PearsonR
# Gene kalrn has invalid predictions/counts and thus has a nan PearsonR
# Gene ap3b1 has invalid predictions/counts and thus has a nan PearsonR
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# Gene prxl2c has invalid predictions/counts and thus has a nan PearsonR
# Gene cep41 has invalid predictions/counts and thus has a nan PearsonR
# Gene plxdc2 has invalid predictions/counts and thus has a nan PearsonR
# Gene rfx3-as1 has invalid predictions/counts and thus has a nan PearsonR
# Gene kiaa1217 has invalid predictions/counts and thus has a nan PearsonR
# Gene tnik has invalid predictions/counts and thus has a nan PearsonR
# Gene ptpre has invalid predictions/counts and thus has a nan PearsonR
# Gene bx088651.4 has invalid predictions/counts and thus has a nan PearsonR
# Gene sec24b-as1 has invalid predictions/counts and thus has a nan PearsonR
# Gene ac090825.1 has no predictions/counts and thus has a nan PearsonR
# Gene dhrs4 has no predictions/counts and thus has a nan PearsonR
# Gene cables2 has no predictions/counts and thus has a nan PearsonR
# Gene srp14-as1 has no predictions/counts and thus has a nan PearsonR
# Gene ac092384.1 has no predictions/counts and thus has a nan PearsonR
# Gene rab15 has no predictions/counts and thus has a nan PearsonR
# Gene blk has no predictions/counts and thus has a nan PearsonR
# Gene hdgfl3 has no predictions/counts and thus has a nan PearsonR
# Gene flywch2 has no predictions/counts and thus has a nan PearsonR
# Gene csnk2a2 has no predictions/counts and thus has a nan PearsonR
# Gene pheta2 has no predictions/counts and thus has a nan PearsonR
# Gene nfatc4 has no predictions/counts and thus has a nan PearsonR
# Gene acyp1 has no predictions/counts and thus has a nan PearsonR
# Gene c15orf39 has no predictions/counts and thus has a nan PearsonR
# Gene cetp has no predictions/counts and thus has a nan PearsonR
# Gene adamts7 has no predictions/counts and thus has a nan PearsonR
# Gene mex3c has no predictions/counts and thus has a nan PearsonR
# Gene golga8a has no predictions/counts and thus has a nan PearsonR
# Gene mei1 has no predictions/counts and thus has a nan PearsonR
# Gene tmed8 has no predictions/counts and thus has a nan PearsonR
# Gene tubb1 has no predictions/counts and thus has a nan PearsonR
# Gene mark3 has no predictions/counts and thus has a nan PearsonR
# Gene mt1e has no predictions/counts and thus has a nan PearsonR
# Gene psmf1 has no predictions/counts and thus has a nan PearsonR
# Gene chmp4c has no predictions/counts and thus has a nan PearsonR
# Gene il16 has no predictions/counts and thus has a nan PearsonR
# Gene dsc2 has no predictions/counts and thus has a nan PearsonR
# Gene wrn has no predictions/counts and thus has a nan PearsonR
# Gene pacsin2 has no predictions/counts and thus has a nan PearsonR
# Gene wars1 has no predictions/counts and thus has a nan PearsonR
# Gene mettl4 has no predictions/counts and thus has a nan PearsonR
# Gene nudt7 has no predictions/counts and thus has a nan PearsonR
# Gene birc7 has no predictions/counts and thus has a nan PearsonR
# Gene bcas1 has no predictions/counts and thus has a nan PearsonR
# Gene smchd1 has no predictions/counts and thus has a nan PearsonR
# Gene al391095.1 has no predictions/counts and thus has a nan PearsonR
# Gene cep76 has no predictions/counts and thus has a nan PearsonR
# Gene mybl2 has no predictions/counts and thus has a nan PearsonR
# Gene c20orf96 has no predictions/counts and thus has a nan PearsonR
# Gene loc101927815 has no predictions/counts and thus has a nan PearsonR
# Gene csgalnact1 has no predictions/counts and thus has a nan PearsonR
# Gene c15orf65 has no predictions/counts and thus has a nan PearsonR
# Gene tnfrsf10a has no predictions/counts and thus has a nan PearsonR
# Gene vapb has no predictions/counts and thus has a nan PearsonR
# Gene l2hgdh has no predictions/counts and thus has a nan PearsonR
# Gene ly6e-dt has no predictions/counts and thus has a nan PearsonR
# Gene fam167a has no predictions/counts and thus has a nan PearsonR
# Gene fam174b has no predictions/counts and thus has a nan PearsonR
# Gene neo1 has no predictions/counts and thus has a nan PearsonR
# Gene cbln3 has no predictions/counts and thus has a nan PearsonR
# Gene dcaf4 has no predictions/counts and thus has a nan PearsonR
# Gene dok6 has no predictions/counts and thus has a nan PearsonR
# Gene rida has no predictions/counts and thus has a nan PearsonR
# Gene slc7a7 has no predictions/counts and thus has a nan PearsonR
# Gene linc02328 has no predictions/counts and thus has a nan PearsonR
# Gene trpa1 has no predictions/counts and thus has a nan PearsonR
# Gene gprc5b has no predictions/counts and thus has a nan PearsonR
# Gene marveld3 has no predictions/counts and thus has a nan PearsonR
# Gene colec12 has no predictions/counts and thus has a nan PearsonR
# Gene ttll12 has no predictions/counts and thus has a nan PearsonR
# Gene tk2 has no predictions/counts and thus has a nan PearsonR
# Gene cecr7 has no predictions/counts and thus has a nan PearsonR
# Gene lonrf1 has no predictions/counts and thus has a nan PearsonR
# Gene cklf has no predictions/counts and thus has a nan PearsonR
# Gene dhrs1 has no predictions/counts and thus has a nan PearsonR
# Gene akap5 has no predictions/counts and thus has a nan PearsonR
# Gene ndrg1 has no predictions/counts and thus has a nan PearsonR
# Gene fto has no predictions/counts and thus has a nan PearsonR
# Gene mtfr1 has no predictions/counts and thus has a nan PearsonR
# Gene al157838.1 has no predictions/counts and thus has a nan PearsonR
# Gene smim19 has no predictions/counts and thus has a nan PearsonR
# Gene ac005606.2 has no predictions/counts and thus has a nan PearsonR
# Gene apobr has no predictions/counts and thus has a nan PearsonR
# Gene cbfa2t3 has no predictions/counts and thus has a nan PearsonR
# Gene acss1 has no predictions/counts and thus has a nan PearsonR
# Gene parvg has no predictions/counts and thus has a nan PearsonR
# Gene hsbp1l1 has no predictions/counts and thus has a nan PearsonR
# Gene maff has no predictions/counts and thus has a nan PearsonR
# Gene znf396 has no predictions/counts and thus has a nan PearsonR
# Gene c18orf32 has no predictions/counts and thus has a nan PearsonR
# Gene dgat1 has no predictions/counts and thus has a nan PearsonR
# Gene znf696 has no predictions/counts and thus has a nan PearsonR
# Gene cltcl1 has no predictions/counts and thus has a nan PearsonR
# Gene npipa3 has no predictions/counts and thus has a nan PearsonR
# Gene kiaa0930 has no predictions/counts and thus has a nan PearsonR
# Gene golga6l9 has no predictions/counts and thus has a nan PearsonR
# Gene loc101929709 has no predictions/counts and thus has a nan PearsonR
# Gene sdr42e1 has no predictions/counts and thus has a nan PearsonR
# Gene loc100128108 has no predictions/counts and thus has a nan PearsonR
# Gene dusp18 has no predictions/counts and thus has a nan PearsonR
# Gene ac141586.2 has no predictions/counts and thus has a nan PearsonR
# Gene mmp14 has no predictions/counts and thus has a nan PearsonR
# Gene syngr1 has no predictions/counts and thus has a nan PearsonR
# Gene al157871.1 has no predictions/counts and thus has a nan PearsonR
# Gene nae1 has no predictions/counts and thus has a nan PearsonR
# Gene rmc1 has no predictions/counts and thus has a nan PearsonR
# Gene gdpgp1 has no predictions/counts and thus has a nan PearsonR
# Gene oprl1 has no predictions/counts and thus has a nan PearsonR
# Gene catsper2 has no predictions/counts and thus has a nan PearsonR
# Gene fanca has no predictions/counts and thus has a nan PearsonR
# Gene a1bg has no predictions/counts and thus has a nan PearsonR
# Gene a4galt has no predictions/counts and thus has a nan PearsonR
# Gene aanat has no predictions/counts and thus has a nan PearsonR
# Gene aasdh has no predictions/counts and thus has a nan PearsonR
# Gene abcb6 has no predictions/counts and thus has a nan PearsonR
# Gene abcd2 has no predictions/counts and thus has a nan PearsonR
# Gene abhd12 has no predictions/counts and thus has a nan PearsonR
# Gene abhd15 has no predictions/counts and thus has a nan PearsonR
# Gene abhd16b has no predictions/counts and thus has a nan PearsonR
# Gene abhd6 has no predictions/counts and thus has a nan PearsonR
# Gene abhd8 has no predictions/counts and thus has a nan PearsonR
# Gene abracl has no predictions/counts and thus has a nan PearsonR
# Gene abraxas1 has no predictions/counts and thus has a nan PearsonR
# Gene abt1 has no predictions/counts and thus has a nan PearsonR
# Gene ac000068.1 has no predictions/counts and thus has a nan PearsonR
# Gene ac003965.1 has no predictions/counts and thus has a nan PearsonR
# Gene ac005670.3 has no predictions/counts and thus has a nan PearsonR
# Gene ac006001.3 has no predictions/counts and thus has a nan PearsonR
# Gene ac006504.1 has no predictions/counts and thus has a nan PearsonR
# Gene ac007036.1 has no predictions/counts and thus has a nan PearsonR
# Gene ac007114.1 has no predictions/counts and thus has a nan PearsonR
# Gene ac007952.1 has no predictions/counts and thus has a nan PearsonR
# Gene ac007952.2 has no predictions/counts and thus has a nan PearsonR
# Gene ac007952.5 has no predictions/counts and thus has a nan PearsonR
# Gene ac008870.1 has no predictions/counts and thus has a nan PearsonR
# Gene ac009779.3 has no predictions/counts and thus has a nan PearsonR
# Gene ac010542.2 has no predictions/counts and thus has a nan PearsonR
# Gene ac011450.1 has no predictions/counts and thus has a nan PearsonR
# Gene ac012368.1 has no predictions/counts and thus has a nan PearsonR
# Gene ac016026.1 has no predictions/counts and thus has a nan PearsonR
# Gene ac017071.1 has no predictions/counts and thus has a nan PearsonR
# Gene ac023906.3 has no predictions/counts and thus has a nan PearsonR
# Gene ac025176.1 has no predictions/counts and thus has a nan PearsonR
# Gene ac026333.3 has no predictions/counts and thus has a nan PearsonR
# Gene ac026904.1 has no predictions/counts and thus has a nan PearsonR
# Gene ac027796.3 has no predictions/counts and thus has a nan PearsonR
# Gene ac069185.1 has no predictions/counts and thus has a nan PearsonR
# Gene ac073655.2 has no predictions/counts and thus has a nan PearsonR
# Gene ac079922.2 has no predictions/counts and thus has a nan PearsonR
# Gene ac084048.1 has no predictions/counts and thus has a nan PearsonR
# Gene ac084757.3 has no predictions/counts and thus has a nan PearsonR
# Gene ac091167.1 has no predictions/counts and thus has a nan PearsonR
# Gene ac092803.1 has no predictions/counts and thus has a nan PearsonR
# Gene ac093323.1 has no predictions/counts and thus has a nan PearsonR
# Gene ac096677.2 has no predictions/counts and thus has a nan PearsonR
# Gene ac104232.1 has no predictions/counts and thus has a nan PearsonR
# Gene ac104794.3 has no predictions/counts and thus has a nan PearsonR
# Gene ac104825.1 has no predictions/counts and thus has a nan PearsonR
# Gene ac105052.1 has no predictions/counts and thus has a nan PearsonR
# Gene ac107068.1 has no predictions/counts and thus has a nan PearsonR
# Gene ac108134.3 has no predictions/counts and thus has a nan PearsonR
# Gene ac112484.3 has no predictions/counts and thus has a nan PearsonR
# Gene ac124944.2 has no predictions/counts and thus has a nan PearsonR
# Gene ac131971.1 has no predictions/counts and thus has a nan PearsonR
# Gene ac136475.1 has no predictions/counts and thus has a nan PearsonR
# Gene ac136475.5 has no predictions/counts and thus has a nan PearsonR
# Gene ac233280.1 has no predictions/counts and thus has a nan PearsonR
# Gene acacb has no predictions/counts and thus has a nan PearsonR
# Gene acad11 has no predictions/counts and thus has a nan PearsonR
# Gene acad9 has no predictions/counts and thus has a nan PearsonR
# Gene acadvl has no predictions/counts and thus has a nan PearsonR
# Gene acap1 has no predictions/counts and thus has a nan PearsonR
# Gene acat2 has no predictions/counts and thus has a nan PearsonR
# Gene accs has no predictions/counts and thus has a nan PearsonR
# Gene acer2 has no predictions/counts and thus has a nan PearsonR
# Gene ackr4 has no predictions/counts and thus has a nan PearsonR
# Gene acot1 has no predictions/counts and thus has a nan PearsonR
# Gene acot2 has no predictions/counts and thus has a nan PearsonR
# Gene acot4 has no predictions/counts and thus has a nan PearsonR
# Gene acot8 has no predictions/counts and thus has a nan PearsonR
# Gene acp1 has no predictions/counts and thus has a nan PearsonR
# Gene acp2 has no predictions/counts and thus has a nan PearsonR
# Gene acp3 has no predictions/counts and thus has a nan PearsonR
# Gene acp6 has no predictions/counts and thus has a nan PearsonR
# Gene acsbg2 has no predictions/counts and thus has a nan PearsonR
# Gene acta2 has no predictions/counts and thus has a nan PearsonR
# Gene actn1 has no predictions/counts and thus has a nan PearsonR
# Gene actr1a has no predictions/counts and thus has a nan PearsonR
# Gene actr5 has no predictions/counts and thus has a nan PearsonR
# Gene actr8 has no predictions/counts and thus has a nan PearsonR
# Gene acvr2a has no predictions/counts and thus has a nan PearsonR
# Gene adal has no predictions/counts and thus has a nan PearsonR
# Gene adam11 has no predictions/counts and thus has a nan PearsonR
# Gene adam19 has no predictions/counts and thus has a nan PearsonR
# Gene adap1 has no predictions/counts and thus has a nan PearsonR
# Gene adap2 has no predictions/counts and thus has a nan PearsonR
# Gene adck1 has no predictions/counts and thus has a nan PearsonR
# Gene adcy3 has no predictions/counts and thus has a nan PearsonR
# Gene adgrd1 has no predictions/counts and thus has a nan PearsonR
# Gene adgre2 has no predictions/counts and thus has a nan PearsonR
# Gene adgrl1 has no predictions/counts and thus has a nan PearsonR
# Gene adi1 has no predictions/counts and thus has a nan PearsonR
# Gene ado has no predictions/counts and thus has a nan PearsonR
# Gene adora2b has no predictions/counts and thus has a nan PearsonR
# Gene adprh has no predictions/counts and thus has a nan PearsonR
# Gene adprhl1 has no predictions/counts and thus has a nan PearsonR
# Gene adrb1 has no predictions/counts and thus has a nan PearsonR
# Gene adrb2 has no predictions/counts and thus has a nan PearsonR
# Gene adss2 has no predictions/counts and thus has a nan PearsonR
# Gene adtrp has no predictions/counts and thus has a nan PearsonR
# Gene aebp1 has no predictions/counts and thus has a nan PearsonR
# Gene aen has no predictions/counts and thus has a nan PearsonR
# Gene af131215.5 has no predictions/counts and thus has a nan PearsonR
# Gene aftph-dt has no predictions/counts and thus has a nan PearsonR
# Gene aga has no predictions/counts and thus has a nan PearsonR
# Gene agap9 has no predictions/counts and thus has a nan PearsonR
# Gene agbl3 has no predictions/counts and thus has a nan PearsonR
# Gene agl has no predictions/counts and thus has a nan PearsonR
# Gene agmat has no predictions/counts and thus has a nan PearsonR
# Gene ago3 has no predictions/counts and thus has a nan PearsonR
# Gene agtrap has no predictions/counts and thus has a nan PearsonR
# Gene ahcy has no predictions/counts and thus has a nan PearsonR
# Gene ahi1 has no predictions/counts and thus has a nan PearsonR
# Gene ahsa2p has no predictions/counts and thus has a nan PearsonR
# Gene aif1 has no predictions/counts and thus has a nan PearsonR
# Gene aim2 has no predictions/counts and thus has a nan PearsonR
# Gene aimp1 has no predictions/counts and thus has a nan PearsonR
# Gene ak3 has no predictions/counts and thus has a nan PearsonR
# Gene ak9 has no predictions/counts and thus has a nan PearsonR
# Gene akap3 has no predictions/counts and thus has a nan PearsonR
# Gene akap7 has no predictions/counts and thus has a nan PearsonR
# Gene akip1 has no predictions/counts and thus has a nan PearsonR
# Gene akirin1 has no predictions/counts and thus has a nan PearsonR
# Gene akirin2 has no predictions/counts and thus has a nan PearsonR
# Gene akr1c1 has no predictions/counts and thus has a nan PearsonR
# Gene akr7a2 has no predictions/counts and thus has a nan PearsonR
# Gene akt1s1 has no predictions/counts and thus has a nan PearsonR
# Gene al022316.1 has no predictions/counts and thus has a nan PearsonR
# Gene al031123.2 has no predictions/counts and thus has a nan PearsonR
# Gene al031282.1 has no predictions/counts and thus has a nan PearsonR
# Gene al035071.1 has no predictions/counts and thus has a nan PearsonR
# Gene al121992.1 has no predictions/counts and thus has a nan PearsonR
# Gene al132656.2 has no predictions/counts and thus has a nan PearsonR
# Gene al133467.1 has no predictions/counts and thus has a nan PearsonR
# Gene al157944.1 has no predictions/counts and thus has a nan PearsonR
# Gene al355075.3 has no predictions/counts and thus has a nan PearsonR
# Gene al365205.1 has no predictions/counts and thus has a nan PearsonR
# Gene al390728.5 has no predictions/counts and thus has a nan PearsonR
# Gene al391832.1 has no predictions/counts and thus has a nan PearsonR
# Gene al513548.1 has no predictions/counts and thus has a nan PearsonR
# Gene al669831.1 has no predictions/counts and thus has a nan PearsonR
# Gene al669918.1 has no predictions/counts and thus has a nan PearsonR
# Gene al691447.2 has no predictions/counts and thus has a nan PearsonR
# Gene aldh16a1 has no predictions/counts and thus has a nan PearsonR
# Gene aldh1l2 has no predictions/counts and thus has a nan PearsonR
# Gene aldh5a1 has no predictions/counts and thus has a nan PearsonR
# Gene aldh7a1 has no predictions/counts and thus has a nan PearsonR
# Gene aldh8a1 has no predictions/counts and thus has a nan PearsonR
# Gene aldh9a1 has no predictions/counts and thus has a nan PearsonR
# Gene alg1l has no predictions/counts and thus has a nan PearsonR
# Gene alg8 has no predictions/counts and thus has a nan PearsonR
# Gene alkbh5 has no predictions/counts and thus has a nan PearsonR
# Gene alms1 has no predictions/counts and thus has a nan PearsonR
# Gene alox5 has no predictions/counts and thus has a nan PearsonR
# Gene amacr has no predictions/counts and thus has a nan PearsonR
# Gene amigo1 has no predictions/counts and thus has a nan PearsonR
# Gene amt has no predictions/counts and thus has a nan PearsonR
# Gene amz2 has no predictions/counts and thus has a nan PearsonR
# Gene anapc13 has no predictions/counts and thus has a nan PearsonR
# Gene anapc16 has no predictions/counts and thus has a nan PearsonR
# Gene angptl6 has no predictions/counts and thus has a nan PearsonR
# Gene ank1 has no predictions/counts and thus has a nan PearsonR
# Gene ank3 has no predictions/counts and thus has a nan PearsonR
# Gene ankdd1a has no predictions/counts and thus has a nan PearsonR
# Gene ankef1 has no predictions/counts and thus has a nan PearsonR
# Gene ankle1 has no predictions/counts and thus has a nan PearsonR
# Gene ankrd20a4p has no predictions/counts and thus has a nan PearsonR
# Gene ankrd44 has no predictions/counts and thus has a nan PearsonR
# Gene ankrd54 has no predictions/counts and thus has a nan PearsonR
# Gene ankrd65 has no predictions/counts and thus has a nan PearsonR
# Gene anks6 has no predictions/counts and thus has a nan PearsonR
# Gene ano7 has no predictions/counts and thus has a nan PearsonR
# Gene ano9 has no predictions/counts and thus has a nan PearsonR
# Gene anxa11 has no predictions/counts and thus has a nan PearsonR
# Gene anxa3 has no predictions/counts and thus has a nan PearsonR
# Gene aopep has no predictions/counts and thus has a nan PearsonR
# Gene ap000295.1 has no predictions/counts and thus has a nan PearsonR
# Gene ap000766.1 has no predictions/counts and thus has a nan PearsonR
# Gene ap000769.1 has no predictions/counts and thus has a nan PearsonR
# Gene ap001267.1 has no predictions/counts and thus has a nan PearsonR
# Gene ap001341.1 has no predictions/counts and thus has a nan PearsonR
# Gene ap002761.2 has no predictions/counts and thus has a nan PearsonR
# Gene ap002856.3 has no predictions/counts and thus has a nan PearsonR
# Gene ap003486.1 has no predictions/counts and thus has a nan PearsonR
# Gene ap3m2 has no predictions/counts and thus has a nan PearsonR
# Gene ap3s2 has no predictions/counts and thus has a nan PearsonR
# Gene ap4b1-as1 has no predictions/counts and thus has a nan PearsonR
# Gene ap5b1 has no predictions/counts and thus has a nan PearsonR
# Gene ap5s1 has no predictions/counts and thus has a nan PearsonR
# Gene apbb1ip has no predictions/counts and thus has a nan PearsonR
# Gene aph1a has no predictions/counts and thus has a nan PearsonR
# Gene apip has no predictions/counts and thus has a nan PearsonR
# Gene aplp1 has no predictions/counts and thus has a nan PearsonR
# Gene apobec3a has no predictions/counts and thus has a nan PearsonR
# Gene apobec3b has no predictions/counts and thus has a nan PearsonR
# Gene apobec3d has no predictions/counts and thus has a nan PearsonR
# Gene apol3 has no predictions/counts and thus has a nan PearsonR
# Gene apol4 has no predictions/counts and thus has a nan PearsonR
# Gene apold1 has no predictions/counts and thus has a nan PearsonR
# Gene aptr has no predictions/counts and thus has a nan PearsonR
# Gene aqp1 has no predictions/counts and thus has a nan PearsonR
# Gene aqp9 has no predictions/counts and thus has a nan PearsonR
# Gene arfip1 has no predictions/counts and thus has a nan PearsonR
# Gene arhgap25 has no predictions/counts and thus has a nan PearsonR
# Gene arhgap27 has no predictions/counts and thus has a nan PearsonR
# Gene arhgef19 has no predictions/counts and thus has a nan PearsonR
# Gene arhgef4 has no predictions/counts and thus has a nan PearsonR
# Gene arhgef40 has no predictions/counts and thus has a nan PearsonR
# Gene arhgef7 has no predictions/counts and thus has a nan PearsonR
# Gene arid4a has no predictions/counts and thus has a nan PearsonR
# Gene arl11 has no predictions/counts and thus has a nan PearsonR
# Gene arl16 has no predictions/counts and thus has a nan PearsonR
# Gene arl17a has no predictions/counts and thus has a nan PearsonR
# Gene arl17b has no predictions/counts and thus has a nan PearsonR
# Gene arl3 has no predictions/counts and thus has a nan PearsonR
# Gene arl4c has no predictions/counts and thus has a nan PearsonR
# Gene arl5b has no predictions/counts and thus has a nan PearsonR
# Gene arl6ip5 has no predictions/counts and thus has a nan PearsonR
# Gene armc1 has no predictions/counts and thus has a nan PearsonR
# Gene armh3 has no predictions/counts and thus has a nan PearsonR
# Gene arrb1 has no predictions/counts and thus has a nan PearsonR
# Gene arrdc1-as1 has no predictions/counts and thus has a nan PearsonR
# Gene arsa has no predictions/counts and thus has a nan PearsonR
# Gene arsb has no predictions/counts and thus has a nan PearsonR
# Gene arv1 has no predictions/counts and thus has a nan PearsonR
# Gene as3mt has no predictions/counts and thus has a nan PearsonR
# Gene asah2 has no predictions/counts and thus has a nan PearsonR
# Gene asah2b has no predictions/counts and thus has a nan PearsonR
# Gene asb13 has no predictions/counts and thus has a nan PearsonR
# Gene asb16 has no predictions/counts and thus has a nan PearsonR
# Gene asb6 has no predictions/counts and thus has a nan PearsonR
# Gene asf1a has no predictions/counts and thus has a nan PearsonR
# Gene asf1b has no predictions/counts and thus has a nan PearsonR
# Gene asrgl1 has no predictions/counts and thus has a nan PearsonR
# Gene atf5 has no predictions/counts and thus has a nan PearsonR
# Gene atf6b has no predictions/counts and thus has a nan PearsonR
# Gene atg10 has no predictions/counts and thus has a nan PearsonR
# Gene atg4c has no predictions/counts and thus has a nan PearsonR
# Gene atl2 has no predictions/counts and thus has a nan PearsonR
# Gene atp10d has no predictions/counts and thus has a nan PearsonR
# Gene atp13a4 has no predictions/counts and thus has a nan PearsonR
# Gene atp1a1-as1 has no predictions/counts and thus has a nan PearsonR
# Gene atp23 has no predictions/counts and thus has a nan PearsonR
# Gene atp2c2 has no predictions/counts and thus has a nan PearsonR
# Gene atp5mc2 has no predictions/counts and thus has a nan PearsonR
# Gene atp6ap1l has no predictions/counts and thus has a nan PearsonR
# Gene atp6v0e2 has no predictions/counts and thus has a nan PearsonR
# Gene atp6v0e2-as1 has no predictions/counts and thus has a nan PearsonR
# Gene atp6v1e1 has no predictions/counts and thus has a nan PearsonR
# Gene atp6v1e2 has no predictions/counts and thus has a nan PearsonR
# Gene atp8b4 has no predictions/counts and thus has a nan PearsonR
# Gene atpaf2 has no predictions/counts and thus has a nan PearsonR
# Gene atraid has no predictions/counts and thus has a nan PearsonR
# Gene aurkc has no predictions/counts and thus has a nan PearsonR
# Gene aven has no predictions/counts and thus has a nan PearsonR
# Gene axin2 has no predictions/counts and thus has a nan PearsonR
# Gene b3galnt2 has no predictions/counts and thus has a nan PearsonR
# Gene b3galt6 has no predictions/counts and thus has a nan PearsonR
# Gene b3glct has no predictions/counts and thus has a nan PearsonR
# Gene b3gntl1 has no predictions/counts and thus has a nan PearsonR
# Gene b4galnt3 has no predictions/counts and thus has a nan PearsonR
# Gene b4galt5 has no predictions/counts and thus has a nan PearsonR
# Gene b4galt7 has no predictions/counts and thus has a nan PearsonR
# Gene b9d2 has no predictions/counts and thus has a nan PearsonR
# Gene baiap2 has no predictions/counts and thus has a nan PearsonR
# Gene bak1 has no predictions/counts and thus has a nan PearsonR
# Gene bambi has no predictions/counts and thus has a nan PearsonR
# Gene batf3 has no predictions/counts and thus has a nan PearsonR
# Gene bbs2 has no predictions/counts and thus has a nan PearsonR
# Gene bbs7 has no predictions/counts and thus has a nan PearsonR
# Gene bckdha has no predictions/counts and thus has a nan PearsonR
# Gene bcl10 has no predictions/counts and thus has a nan PearsonR
# Gene bcr has no predictions/counts and thus has a nan PearsonR
# Gene begain has no predictions/counts and thus has a nan PearsonR
# Gene bend3 has no predictions/counts and thus has a nan PearsonR
# Gene bend6 has no predictions/counts and thus has a nan PearsonR
# Gene bet1 has no predictions/counts and thus has a nan PearsonR
# Gene bfsp2 has no predictions/counts and thus has a nan PearsonR
# Gene bicd2 has no predictions/counts and thus has a nan PearsonR
# Gene bik has no predictions/counts and thus has a nan PearsonR
# Gene bloc1s1 has no predictions/counts and thus has a nan PearsonR
# Gene bloc1s2 has no predictions/counts and thus has a nan PearsonR
# Gene bmp1 has no predictions/counts and thus has a nan PearsonR
# Gene bmp8a has no predictions/counts and thus has a nan PearsonR
# Gene bmp8b has no predictions/counts and thus has a nan PearsonR
# Gene bnip1 has no predictions/counts and thus has a nan PearsonR
# Gene bola2-smg1p6 has no predictions/counts and thus has a nan PearsonR
# Gene bpgm has no predictions/counts and thus has a nan PearsonR
# Gene bphl has no predictions/counts and thus has a nan PearsonR
# Gene bptf has no predictions/counts and thus has a nan PearsonR
# Gene braf has no predictions/counts and thus has a nan PearsonR
# Gene brip1 has no predictions/counts and thus has a nan PearsonR
# Gene btn2a1 has no predictions/counts and thus has a nan PearsonR
# Gene btn2a2 has no predictions/counts and thus has a nan PearsonR
# Gene btn3a1 has no predictions/counts and thus has a nan PearsonR
# Gene btn3a2 has no predictions/counts and thus has a nan PearsonR
# Gene btn3a3 has no predictions/counts and thus has a nan PearsonR
# Gene btnl9 has no predictions/counts and thus has a nan PearsonR
# Gene bx005266.2 has no predictions/counts and thus has a nan PearsonR
# Gene c10orf143 has no predictions/counts and thus has a nan PearsonR
# Gene c10orf88 has no predictions/counts and thus has a nan PearsonR
# Gene c11orf24 has no predictions/counts and thus has a nan PearsonR
# Gene c11orf54 has no predictions/counts and thus has a nan PearsonR
# Gene c12orf60 has no predictions/counts and thus has a nan PearsonR
# Gene c14orf119 has no predictions/counts and thus has a nan PearsonR
# Gene c16orf95 has no predictions/counts and thus has a nan PearsonR
# Gene c17orf75 has no predictions/counts and thus has a nan PearsonR
# Gene c17orf97 has no predictions/counts and thus has a nan PearsonR
# Gene c17orf99 has no predictions/counts and thus has a nan PearsonR
# Gene c18orf21 has no predictions/counts and thus has a nan PearsonR
# Gene c18orf54 has no predictions/counts and thus has a nan PearsonR
# Gene c19orf47 has no predictions/counts and thus has a nan PearsonR
# Gene c19orf48 has no predictions/counts and thus has a nan PearsonR
# Gene c19orf53 has no predictions/counts and thus has a nan PearsonR
# Gene c19orf54 has no predictions/counts and thus has a nan PearsonR
# Gene c19orf84 has no predictions/counts and thus has a nan PearsonR
# Gene c1galt1 has no predictions/counts and thus has a nan PearsonR
# Gene c1orf115 has no predictions/counts and thus has a nan PearsonR
# Gene c1orf167 has no predictions/counts and thus has a nan PearsonR
# Gene c1orf174 has no predictions/counts and thus has a nan PearsonR
# Gene c1orf198 has no predictions/counts and thus has a nan PearsonR
# Gene c1ql3 has no predictions/counts and thus has a nan PearsonR
# Gene c1qtnf6 has no predictions/counts and thus has a nan PearsonR
# Gene c1qtnf9 has no predictions/counts and thus has a nan PearsonR
# Gene c1qtnf9b has no predictions/counts and thus has a nan PearsonR
# Gene c2 has no predictions/counts and thus has a nan PearsonR
# Gene c20orf204 has no predictions/counts and thus has a nan PearsonR
# Gene c20orf27 has no predictions/counts and thus has a nan PearsonR
# Gene c22orf34 has no predictions/counts and thus has a nan PearsonR
# Gene c2orf72 has no predictions/counts and thus has a nan PearsonR
# Gene c2orf74 has no predictions/counts and thus has a nan PearsonR
# Gene c3orf20 has no predictions/counts and thus has a nan PearsonR
# Gene c3orf52 has no predictions/counts and thus has a nan PearsonR
# Gene c4bpb has no predictions/counts and thus has a nan PearsonR
# Gene c5ar1 has no predictions/counts and thus has a nan PearsonR
# Gene c6orf120 has no predictions/counts and thus has a nan PearsonR
# Gene c6orf163 has no predictions/counts and thus has a nan PearsonR
# Gene c6orf62 has no predictions/counts and thus has a nan PearsonR
# Gene c8orf37 has no predictions/counts and thus has a nan PearsonR
# Gene c9orf43 has no predictions/counts and thus has a nan PearsonR
# Gene c9orf64 has no predictions/counts and thus has a nan PearsonR
# Gene c9orf72 has no predictions/counts and thus has a nan PearsonR
# Gene ca4 has no predictions/counts and thus has a nan PearsonR
# Gene cab39 has no predictions/counts and thus has a nan PearsonR
# Gene cabyr has no predictions/counts and thus has a nan PearsonR
# Gene cacna1e has no predictions/counts and thus has a nan PearsonR
# Gene cacnb3 has no predictions/counts and thus has a nan PearsonR
# Gene cactin has no predictions/counts and thus has a nan PearsonR
# Gene calcoco2 has no predictions/counts and thus has a nan PearsonR
# Gene calhm6 has no predictions/counts and thus has a nan PearsonR
# Gene calm1 has no predictions/counts and thus has a nan PearsonR
# Gene camk4 has no predictions/counts and thus has a nan PearsonR
# Gene camkk1 has no predictions/counts and thus has a nan PearsonR
# Gene camlg has no predictions/counts and thus has a nan PearsonR
# Gene camsap3 has no predictions/counts and thus has a nan PearsonR
# Gene cand2 has no predictions/counts and thus has a nan PearsonR
# Gene capg has no predictions/counts and thus has a nan PearsonR
# Gene capn11 has no predictions/counts and thus has a nan PearsonR
# Gene capn12 has no predictions/counts and thus has a nan PearsonR
# Gene capn14 has no predictions/counts and thus has a nan PearsonR
# Gene caps has no predictions/counts and thus has a nan PearsonR
# Gene capza1 has no predictions/counts and thus has a nan PearsonR
# Gene card6 has no predictions/counts and thus has a nan PearsonR
# Gene card9 has no predictions/counts and thus has a nan PearsonR
# Gene carm1 has no predictions/counts and thus has a nan PearsonR
# Gene carmil1 has no predictions/counts and thus has a nan PearsonR
# Gene cars2 has no predictions/counts and thus has a nan PearsonR
# Gene casc3 has no predictions/counts and thus has a nan PearsonR
# Gene caskin2 has no predictions/counts and thus has a nan PearsonR
# Gene cast has no predictions/counts and thus has a nan PearsonR
# Gene cat has no predictions/counts and thus has a nan PearsonR
# Gene cav1 has no predictions/counts and thus has a nan PearsonR
# Gene cav2 has no predictions/counts and thus has a nan PearsonR
# Gene cbr1 has no predictions/counts and thus has a nan PearsonR
# Gene cbx2 has no predictions/counts and thus has a nan PearsonR
# Gene cbx8 has no predictions/counts and thus has a nan PearsonR
# Gene ccdc103 has no predictions/counts and thus has a nan PearsonR
# Gene ccdc107 has no predictions/counts and thus has a nan PearsonR
# Gene ccdc113 has no predictions/counts and thus has a nan PearsonR
# Gene ccdc115 has no predictions/counts and thus has a nan PearsonR
# Gene ccdc122 has no predictions/counts and thus has a nan PearsonR
# Gene ccdc125 has no predictions/counts and thus has a nan PearsonR
# Gene ccdc126 has no predictions/counts and thus has a nan PearsonR
# Gene ccdc13 has no predictions/counts and thus has a nan PearsonR
# Gene ccdc134 has no predictions/counts and thus has a nan PearsonR
# Gene ccdc137 has no predictions/counts and thus has a nan PearsonR
# Gene ccdc144a has no predictions/counts and thus has a nan PearsonR
# Gene ccdc15 has no predictions/counts and thus has a nan PearsonR
# Gene ccdc17 has no predictions/counts and thus has a nan PearsonR
# Gene ccdc171 has no predictions/counts and thus has a nan PearsonR
# Gene ccdc184 has no predictions/counts and thus has a nan PearsonR
# Gene ccdc26 has no predictions/counts and thus has a nan PearsonR
# Gene ccdc32 has no predictions/counts and thus has a nan PearsonR
# Gene ccdc65 has no predictions/counts and thus has a nan PearsonR
# Gene ccdc69 has no predictions/counts and thus has a nan PearsonR
# Gene ccdc7 has no predictions/counts and thus has a nan PearsonR
# Gene ccdc74a has no predictions/counts and thus has a nan PearsonR
# Gene ccdc81 has no predictions/counts and thus has a nan PearsonR
# Gene ccdc82 has no predictions/counts and thus has a nan PearsonR
# Gene ccdc9 has no predictions/counts and thus has a nan PearsonR
# Gene ccdc92 has no predictions/counts and thus has a nan PearsonR
# Gene cchcr1 has no predictions/counts and thus has a nan PearsonR
# Gene ccm2 has no predictions/counts and thus has a nan PearsonR
# Gene ccna1 has no predictions/counts and thus has a nan PearsonR
# Gene ccna2 has no predictions/counts and thus has a nan PearsonR
# Gene ccnd1 has no predictions/counts and thus has a nan PearsonR
# Gene ccnyl1 has no predictions/counts and thus has a nan PearsonR
# Gene ccp110 has no predictions/counts and thus has a nan PearsonR
# Gene ccr10 has no predictions/counts and thus has a nan PearsonR
# Gene ccs has no predictions/counts and thus has a nan PearsonR
# Gene ccser2 has no predictions/counts and thus has a nan PearsonR
# Gene cct8 has no predictions/counts and thus has a nan PearsonR
# Gene ccz1 has no predictions/counts and thus has a nan PearsonR
# Gene ccz1b has no predictions/counts and thus has a nan PearsonR
# Gene cd109 has no predictions/counts and thus has a nan PearsonR
# Gene cd151 has no predictions/counts and thus has a nan PearsonR
# Gene cd22 has no predictions/counts and thus has a nan PearsonR
# Gene cd244 has no predictions/counts and thus has a nan PearsonR
# Gene cd28 has no predictions/counts and thus has a nan PearsonR
# Gene cd2bp2 has no predictions/counts and thus has a nan PearsonR
# Gene cd300c has no predictions/counts and thus has a nan PearsonR
# Gene cd37 has no predictions/counts and thus has a nan PearsonR
# Gene cd47 has no predictions/counts and thus has a nan PearsonR
# Gene cd48 has no predictions/counts and thus has a nan PearsonR
# Gene cd72 has no predictions/counts and thus has a nan PearsonR
# Gene cd9 has no predictions/counts and thus has a nan PearsonR
# Gene cdc14b has no predictions/counts and thus has a nan PearsonR
# Gene cdc16 has no predictions/counts and thus has a nan PearsonR
# Gene cdc42 has no predictions/counts and thus has a nan PearsonR
# Gene cdc42ep5 has no predictions/counts and thus has a nan PearsonR
# Gene cdcp1 has no predictions/counts and thus has a nan PearsonR
# Gene cdip1 has no predictions/counts and thus has a nan PearsonR
# Gene cdk10 has no predictions/counts and thus has a nan PearsonR
# Gene cdk2ap1 has no predictions/counts and thus has a nan PearsonR
# Gene cdk7 has no predictions/counts and thus has a nan PearsonR
# Gene cdkal1 has no predictions/counts and thus has a nan PearsonR
# Gene cdkn2aipnl has no predictions/counts and thus has a nan PearsonR
# Gene cdrt15p1 has no predictions/counts and thus has a nan PearsonR
# Gene cdrt15p3 has no predictions/counts and thus has a nan PearsonR
# Gene cdv3 has no predictions/counts and thus has a nan PearsonR
# ...
# Gene zc3h14 has no predictions/counts and thus has a nan PearsonR
# Gene zc3h3 has no predictions/counts and thus has a nan PearsonR
# Gene zcchc4 has no predictions/counts and thus has a nan PearsonR
# Gene zdbf2 has no predictions/counts and thus has a nan PearsonR
# Gene zdhhc2 has no predictions/counts and thus has a nan PearsonR
# Gene zdhhc24 has no predictions/counts and thus has a nan PearsonR
# Gene zdhhc5 has no predictions/counts and thus has a nan PearsonR
# Gene zfand4 has no predictions/counts and thus has a nan PearsonR
# Gene zfp1 has no predictions/counts and thus has a nan PearsonR
# Gene zfp14 has no predictions/counts and thus has a nan PearsonR
# Gene zfp30 has no predictions/counts and thus has a nan PearsonR
# Gene zfp37 has no predictions/counts and thus has a nan PearsonR
# Gene zfp82 has no predictions/counts and thus has a nan PearsonR
# Gene zfp91 has no predictions/counts and thus has a nan PearsonR
# Gene zfyve16 has no predictions/counts and thus has a nan PearsonR
# Gene zfyve19 has no predictions/counts and thus has a nan PearsonR
# Gene zfyve28 has no predictions/counts and thus has a nan PearsonR
# Gene zmynd12 has no predictions/counts and thus has a nan PearsonR
# Gene znf114 has no predictions/counts and thus has a nan PearsonR
# Gene znf132 has no predictions/counts and thus has a nan PearsonR
# Gene znf155 has no predictions/counts and thus has a nan PearsonR
# Gene znf165 has no predictions/counts and thus has a nan PearsonR
# Gene znf175 has no predictions/counts and thus has a nan PearsonR
# Gene znf180 has no predictions/counts and thus has a nan PearsonR
# Gene znf205 has no predictions/counts and thus has a nan PearsonR
# Gene znf213 has no predictions/counts and thus has a nan PearsonR
# Gene znf214 has no predictions/counts and thus has a nan PearsonR
# Gene znf215 has no predictions/counts and thus has a nan PearsonR
# Gene znf217 has no predictions/counts and thus has a nan PearsonR
# Gene znf232 has no predictions/counts and thus has a nan PearsonR
# Gene znf233 has no predictions/counts and thus has a nan PearsonR
# Gene znf239 has no predictions/counts and thus has a nan PearsonR
# Gene znf253 has no predictions/counts and thus has a nan PearsonR
# Gene znf257 has no predictions/counts and thus has a nan PearsonR
# Gene znf263 has no predictions/counts and thus has a nan PearsonR
# Gene znf266 has no predictions/counts and thus has a nan PearsonR
# Gene znf284 has no predictions/counts and thus has a nan PearsonR
# Gene znf286a has no predictions/counts and thus has a nan PearsonR
# Gene znf302 has no predictions/counts and thus has a nan PearsonR
# Gene znf304 has no predictions/counts and thus has a nan PearsonR
# Gene znf320 has no predictions/counts and thus has a nan PearsonR
# Gene znf329 has no predictions/counts and thus has a nan PearsonR
# Gene znf334 has no predictions/counts and thus has a nan PearsonR
# Gene znf347 has no predictions/counts and thus has a nan PearsonR
# Gene znf391 has no predictions/counts and thus has a nan PearsonR
# Gene znf404 has no predictions/counts and thus has a nan PearsonR
# Gene znf419 has no predictions/counts and thus has a nan PearsonR
# Gene znf425 has no predictions/counts and thus has a nan PearsonR
# Gene znf429 has no predictions/counts and thus has a nan PearsonR
# Gene znf43 has no predictions/counts and thus has a nan PearsonR
# Gene znf431 has no predictions/counts and thus has a nan PearsonR
# Gene znf433-as1 has no predictions/counts and thus has a nan PearsonR
# Gene znf443 has no predictions/counts and thus has a nan PearsonR
# Gene znf468 has no predictions/counts and thus has a nan PearsonR
# Gene znf470 has no predictions/counts and thus has a nan PearsonR
# Gene znf480 has no predictions/counts and thus has a nan PearsonR
# Gene znf492 has no predictions/counts and thus has a nan PearsonR
# Gene znf493 has no predictions/counts and thus has a nan PearsonR
# Gene znf497 has no predictions/counts and thus has a nan PearsonR
# Gene znf500 has no predictions/counts and thus has a nan PearsonR
# Gene znf501 has no predictions/counts and thus has a nan PearsonR
# Gene znf502 has no predictions/counts and thus has a nan PearsonR
# Gene znf506 has no predictions/counts and thus has a nan PearsonR
# Gene znf512b has no predictions/counts and thus has a nan PearsonR
# Gene znf514 has no predictions/counts and thus has a nan PearsonR
# Gene znf529 has no predictions/counts and thus has a nan PearsonR
# Gene znf529-as1 has no predictions/counts and thus has a nan PearsonR
# Gene znf548 has no predictions/counts and thus has a nan PearsonR
# Gene znf554 has no predictions/counts and thus has a nan PearsonR
# Gene znf557 has no predictions/counts and thus has a nan PearsonR
# Gene znf559 has no predictions/counts and thus has a nan PearsonR
# Gene znf561 has no predictions/counts and thus has a nan PearsonR
# Gene znf565 has no predictions/counts and thus has a nan PearsonR
# Gene znf567 has no predictions/counts and thus has a nan PearsonR
# Gene znf568 has no predictions/counts and thus has a nan PearsonR
# Gene znf575 has no predictions/counts and thus has a nan PearsonR
# Gene znf577 has no predictions/counts and thus has a nan PearsonR
# Gene znf580 has no predictions/counts and thus has a nan PearsonR
# Gene znf582 has no predictions/counts and thus has a nan PearsonR
# Gene znf584 has no predictions/counts and thus has a nan PearsonR
# Gene znf585a has no predictions/counts and thus has a nan PearsonR
# Gene znf589 has no predictions/counts and thus has a nan PearsonR
# Gene znf593 has no predictions/counts and thus has a nan PearsonR
# Gene znf597 has no predictions/counts and thus has a nan PearsonR
# Gene znf600 has no predictions/counts and thus has a nan PearsonR
# Gene znf606 has no predictions/counts and thus has a nan PearsonR
# Gene znf607 has no predictions/counts and thus has a nan PearsonR
# Gene znf608 has no predictions/counts and thus has a nan PearsonR
# Gene znf665 has no predictions/counts and thus has a nan PearsonR
# Gene znf672 has no predictions/counts and thus has a nan PearsonR
# Gene znf680 has no predictions/counts and thus has a nan PearsonR
# Gene znf681 has no predictions/counts and thus has a nan PearsonR
# Gene znf682 has no predictions/counts and thus has a nan PearsonR
# Gene znf699 has no predictions/counts and thus has a nan PearsonR
# Gene znf708 has no predictions/counts and thus has a nan PearsonR
# Gene znf71 has no predictions/counts and thus has a nan PearsonR
# Gene znf714 has no predictions/counts and thus has a nan PearsonR
# Gene znf717 has no predictions/counts and thus has a nan PearsonR
# Gene znf718 has no predictions/counts and thus has a nan PearsonR
# Gene znf738 has no predictions/counts and thus has a nan PearsonR
# Gene znf77 has no predictions/counts and thus has a nan PearsonR
# Gene znf772 has no predictions/counts and thus has a nan PearsonR
# Gene znf781 has no predictions/counts and thus has a nan PearsonR
# Gene znf784 has no predictions/counts and thus has a nan PearsonR
# Gene znf786 has no predictions/counts and thus has a nan PearsonR
# Gene znf79 has no predictions/counts and thus has a nan PearsonR
# Gene znf790 has no predictions/counts and thus has a nan PearsonR
# Gene znf792 has no predictions/counts and thus has a nan PearsonR
# Gene znf793 has no predictions/counts and thus has a nan PearsonR
# Gene znf814 has no predictions/counts and thus has a nan PearsonR
# Gene znf836 has no predictions/counts and thus has a nan PearsonR
# Gene znf846 has no predictions/counts and thus has a nan PearsonR
# Gene znf85 has no predictions/counts and thus has a nan PearsonR
# Gene znf879 has no predictions/counts and thus has a nan PearsonR
# Gene znf880 has no predictions/counts and thus has a nan PearsonR
# Gene znhit6 has no predictions/counts and thus has a nan PearsonR
# Gene zpbp2 has no predictions/counts and thus has a nan PearsonR
# Gene zscan21 has no predictions/counts and thus has a nan PearsonR
# Gene zscan23 has no predictions/counts and thus has a nan PearsonR
# Gene zswim4 has no predictions/counts and thus has a nan PearsonR
# Gene zxdc has no predictions/counts and thus has a nan PearsonR
# Gene zyg11a has no predictions/counts and thus has a nan PearsonR
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# Gene golga6l9 has invalid predictions/counts and thus has a nan pearsonR
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# Gene ensg00000184779 has invalid predictions/counts and thus has a nan pearsonR
# Gene ensg00000196648 has invalid predictions/counts and thus has a nan pearsonR
# Gene ensg00000197701 has invalid predictions/counts and thus has a nan pearsonR
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# Gene nprl3 has invalid predictions/counts and thus has a nan pearsonR
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# Gene polr3k has invalid predictions/counts and thus has a nan pearsonR
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# Gene snrnp25 has invalid predictions/counts and thus has a nan pearsonR
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# Gene znf718 has invalid predictions/counts and thus has a nan pearsonR
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# Gene golga6l9 has invalid predictions/counts and thus has a nan pearsonR
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# Gene ensg00000184779 has invalid predictions/counts and thus has a nan pearsonR
# Gene ensg00000196648 has invalid predictions/counts and thus has a nan pearsonR
# Gene ensg00000197701 has invalid predictions/counts and thus has a nan pearsonR
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# Gene nprl3 has invalid predictions/counts and thus has a nan pearsonR
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# Gene polr3k has invalid predictions/counts and thus has a nan pearsonR
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# Gene snrnp25 has invalid predictions/counts and thus has a nan pearsonR
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# Gene znf718 has invalid predictions/counts and thus has a nan pearsonR
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# Gene golga6l9 has invalid predictions/counts and thus has a nan pearsonR
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# Gene ensg00000184779 has invalid predictions/counts and thus has a nan pearsonR
# Gene ensg00000196648 has invalid predictions/counts and thus has a nan pearsonR
# Gene ensg00000197701 has invalid predictions/counts and thus has a nan pearsonR
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# Gene nprl3 has invalid predictions/counts and thus has a nan pearsonR
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# Gene polr3k has invalid predictions/counts and thus has a nan pearsonR
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# Gene snrnp25 has invalid predictions/counts and thus has a nan pearsonR
# Gene znf718 has invalid predictions/counts and thus has a nan pearsonR
# /clusterfs/nilah/aniketh/mamba_envs/promoter_models/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))

# %%
gene_perf
# Out:
#          gene    gene_class  baseline_Pearson  predixcan_Pearson  \
# 0       znf83  random_split         -0.003408           0.411355
# 1      eftud2  random_split         -0.028312           0.392380
# 2      tspan4  random_split          0.187495           0.359469
# 3       nucb1  random_split          0.424650           0.372653
# 4       rflnb  random_split          0.109474           0.130039
# ...       ...           ...               ...                ...
# 3254  zscan21        unseen          0.063867           0.000000
# 3255  zscan23        unseen          0.376974           0.000000
# 3256   zswim4        unseen          0.386495           0.000000
# 3257     zxdc        unseen          0.180485           0.000000
# 3258   zyg11a        unseen         -0.047173           0.000000
#
#       finetuned_Pearson_regression_data_seed_42_lr_0.0001_wd_0.001_rcprob_0.5_rsmax_3  \
# 0                                              0.359325
# 1                                              0.345252
# 2                                              0.258073
# 3                                              0.423714
# 4                                              0.224607
# ...                                                 ...
# 3254                                           0.148072
# 3255                                          -0.318505
# 3256                                           0.288827
# 3257                                          -0.186463
# 3258                                           0.047041
#
#       finetuned_Pearson_regression_data_seed_97_lr_0.0001_wd_0.001_rcprob_0.5_rsmax_3  \
# 0                                              0.438791
# 1                                              0.406891
# 2                                              0.320718
# 3                                              0.320159
# 4                                              0.162975
# ...                                                 ...
# 3254                                           0.054715
# 3255                                           0.153711
# 3256                                           0.230592
# 3257                                          -0.099479
# 3258                                          -0.002747
#
#       finetuned_Pearson_regression_data_seed_7_lr_0.0001_wd_0.001_rcprob_0.5_rsmax_3  \
# 0                                              0.335123
# 1                                              0.377886
# 2                                              0.341329
# 3                                              0.376667
# 4                                              0.171352
# ...                                                 ...
# 3254                                           0.040170
# 3255                                          -0.166124
# 3256                                           0.133682
# 3257                                          -0.155037
# 3258                                           0.090260
#
#       Mean Pearson Correlation
# 0                     0.283310
# 1                     0.282507
# 2                     0.230030
# 3                     0.280135
# 4                     0.139733
# ...                        ...
# 3254                  0.060739
# 3255                 -0.082730
# 3256                  0.163275
# 3257                 -0.110245
# 3258                  0.033638
#
# [3259 rows x 8 columns]

# %% [markdown]
# ### Compute the percent of all variants seen during training

# %%
train_h5 = h5py.File(train_h5_path, "r")
train_genes = train_h5["genes"][:].astype(str)

val_h5 = h5py.File(val_h5_path, "r")
val_genes = val_h5["genes"][:].astype(str)

test_genes = test_h5["genes"][:].astype(str)

if not os.path.exists("gene_variant_stats.csv"):
    all_percent_seen_during_training = []
    all_num_train_variants = []
    all_percent_only_seen_during_testing = []
    all_num_only_test = []
    all_num_all_variants = []
    
    for i in tqdm(range(len(gene_perf))):
        row = gene_perf.iloc[i]
        gene_name = row["gene"]
        gene_class = row["gene_class"]
        print(gene_name, gene_class)
        train_gene_seqs = train_h5["seqs"][train_genes == gene_name]
        val_gene_seqs = val_h5["seqs"][val_genes == gene_name]
        test_gene_seqs = test_h5["seqs"][test_genes == gene_name]
    
        # get variants in each split
        train_variants = np.any(train_gene_seqs > 0, axis=(0, 1)) # (seqlen, 4)
        val_variants = np.any(val_gene_seqs > 0, axis=(0, 1))
        test_variants = np.any(test_gene_seqs > 0, axis=(0, 1))
    
        # get all variants
        all_variants = np.stack([train_variants, val_variants, test_variants])
        all_variants = np.any(all_variants, axis=0)
        num_all_variants = (all_variants.sum(-1) > 1).sum()
    
        # compute percent of variants seen in the training set
        # this XOR will find variants that are not present in the train set but are found in the val or test set
        if gene_class == "unseen":
            all_percent_seen_during_training.append(0)
            all_num_train_variants.append(0)
            all_num_all_variants.append(num_all_variants)
            all_percent_only_seen_during_testing.append(100.0)
            all_num_only_test.append(num_all_variants)
        else:
            num_not_seen_in_train = np.logical_xor(all_variants, train_variants).sum()
            num_seen_in_train = num_all_variants - num_not_seen_in_train
            percent_seen_during_training = (num_seen_in_train / num_all_variants) * 100.0
            assert percent_seen_during_training >= 0
            print(f"Num all variants = {num_all_variants}")
            print(f"Num variants seen during training = {num_seen_in_train} ({percent_seen_during_training}%)")
            
            all_percent_seen_during_training.append(percent_seen_during_training)
            all_num_train_variants.append(num_seen_in_train)
            all_num_all_variants.append(num_all_variants)
    
            # compute percent of variants that are only seen in the test set
            # this op will find variants that are present in the test set but are not found in the val or test set
            num_only_seen_in_test = (test_variants & np.logical_not(train_variants | val_variants)).sum()
            percent_only_seen_during_testing = (num_only_seen_in_test / num_all_variants) * 100.0
            print(f"Num variants only seen during testing = {num_only_seen_in_test} ({percent_only_seen_during_testing}%)")
        
            all_percent_only_seen_during_testing.append(percent_only_seen_during_testing)
            all_num_only_test.append(num_only_seen_in_test)
    
    gene_perf["Percent of all variants seen during training"] = all_percent_seen_during_training
    gene_perf["Num variants seen during training"] = all_num_train_variants
    
    gene_perf["Percent of all variants only seen during testing"] = all_percent_only_seen_during_testing
    gene_perf["Num variants only seen during testing"] = all_num_only_test
    
    gene_perf["Num variants"] = all_num_all_variants
    
    gene_perf[gene_perf.columns[:2].tolist() + gene_perf.columns[-6:].tolist()].to_csv("gene_variant_stats.csv", index=False)

gene_variant_stats = pd.read_csv("gene_variant_stats.csv")

# %%
gene_variant_stats
# Out:
#          gene    gene_class  Mean Pearson Correlation  \
# 0       znf83  random_split                  0.377746
# 1      eftud2  random_split                  0.376677
# 2      tspan4  random_split                  0.306707
# 3       nucb1  random_split                  0.373514
# 4       rflnb  random_split                  0.186311
# ..        ...           ...                       ...
# 495      rmc1        unseen                  0.110076
# 496    gdpgp1        unseen                 -0.046663
# 497     oprl1        unseen                  0.089624
# 498  catsper2        unseen                  0.177248
# 499     fanca        unseen                  0.075985
#
#      Percent of all variants seen during training  \
# 0                                       98.021309
# 1                                       96.728972
# 2                                       94.072658
# 3                                       96.153846
# 4                                       97.192982
# ..                                            ...
# 495                                      0.000000
# 496                                      0.000000
# 497                                      0.000000
# 498                                      0.000000
# 499                                      0.000000
#
#      Num variants seen during training  \
# 0                                  644
# 1                                  414
# 2                                  492
# 3                                  525
# 4                                  277
# ..                                 ...
# 495                                  0
# 496                                  0
# 497                                  0
# 498                                  0
# 499                                  0
#
#      Percent of all variants only seen during testing  \
# 0                                            1.369863
# 1                                            2.570093
# 2                                            5.162524
# 3                                            3.296703
# 4                                            2.456140
# ..                                                ...
# 495                                        100.000000
# 496                                        100.000000
# 497                                        100.000000
# 498                                        100.000000
# 499                                        100.000000
#
#      Num variants only seen during testing  Num variants
# 0                                        9           657
# 1                                       11           428
# 2                                       27           523
# 3                                       18           546
# 4                                        7           285
# ..                                     ...           ...
# 495                                    405           405
# 496                                    571           571
# 497                                    370           370
# 498                                     95            95
# 499                                    629           629
#
# [500 rows x 8 columns]

# %% [markdown]
# ## Find strongest eQTL within context window

# %%
if not os.path.exists(os.path.join(data_dir, "YRI_eQTLs_within_context_for_selected_genes.csv")):
    geuvadis_id_to_dbSNP_id = pd.read_csv(os.path.join(geuvadis_genotypes_dir, "Phase1.Geuvadis_dbSnp137_idconvert.txt.gz"), names=["dbSNP_id", "geuvadis_id"], sep="\t")
    geuvadis_id_annotations = pd.read_csv(os.path.join(geuvadis_genotypes_dir, "ALL.phase1_release_v3.20101123.snps_indels_sv.sites.gdid.gdannot.v2.vcf.gz"), skiprows=78, sep="\t")
    geuvadis_id_annotations = geuvadis_id_annotations.merge(geuvadis_id_to_dbSNP_id, left_on="ID", right_on="geuvadis_id", how="inner")
    
    EUR_all_eQTLs_path = os.path.join(geuvadis_eQTL_dir, "EUR373.gene.cis.FDR5.all.rs137.txt.gz")
    YRI_all_eQTLs_path = os.path.join(geuvadis_eQTL_dir, "YRI89.gene.cis.FDR5.all.rs137.txt.gz")
    
    EUR_all_eQTLs = pd.read_csv(EUR_all_eQTLs_path, sep="\t")
    EUR_all_eQTLs = EUR_all_eQTLs[EUR_all_eQTLs["distance"] < (context_size // 2)].reset_index(drop=True)
    EUR_all_eQTLs["abs_rvalue"] = np.abs(EUR_all_eQTLs["rvalue"])
    EUR_all_eQTLs["stable_id"] = EUR_all_eQTLs.apply(lambda x: x["GENE_ID"].split(".")[0], axis=1)
    EUR_all_eQTLs = EUR_all_eQTLs.sort_values(by=["GENE_ID", "abs_rvalue"], ascending=[True, False]).reset_index(drop=True)
    
    YRI_all_eQTLs = pd.read_csv(YRI_all_eQTLs_path, sep="\t")
    YRI_all_eQTLs = YRI_all_eQTLs[YRI_all_eQTLs["distance"] < (context_size // 2)].reset_index(drop=True)
    YRI_all_eQTLs["abs_rvalue"] = np.abs(YRI_all_eQTLs["rvalue"])
    YRI_all_eQTLs["stable_id"] = YRI_all_eQTLs.apply(lambda x: x["GENE_ID"].split(".")[0], axis=1)
    YRI_all_eQTLs = YRI_all_eQTLs.sort_values(by=["GENE_ID", "abs_rvalue"], ascending=[True, False]).reset_index(drop=True)
    
    EUR_all_eQTLs = EUR_all_eQTLs.merge(geuvadis_id_annotations[["dbSNP_id", "geuvadis_id", "#CHROM", "POS", "REF", "ALT", "INFO"]], left_on="SNP_ID", right_on="dbSNP_id", how="inner")
    YRI_all_eQTLs = YRI_all_eQTLs.merge(geuvadis_id_annotations[["dbSNP_id", "geuvadis_id", "#CHROM", "POS", "REF", "ALT", "INFO"]], left_on="SNP_ID", right_on="dbSNP_id", how="inner")
    
    GEUVADIS_COUNTS = pd.read_csv(GEUVADIS_COUNTS_PATH)
    EUR_all_eQTLs = EUR_all_eQTLs.merge(GEUVADIS_COUNTS[["stable_id", "our_gene_name"]], on="stable_id", how="inner")
    YRI_all_eQTLs = YRI_all_eQTLs.merge(GEUVADIS_COUNTS[["stable_id", "our_gene_name"]], on="stable_id", how="inner")
    
    EUR_eQTLs_within_context_for_selected_genes = gene_perf.merge(EUR_all_eQTLs, left_on="gene", right_on="our_gene_name", how="inner")
    EUR_eQTLs_within_context_for_selected_genes = EUR_eQTLs_within_context_for_selected_genes[EUR_eQTLs_within_context_for_selected_genes.columns[8:]]
    EUR_eQTLs_within_context_for_selected_genes.to_csv(os.path.join(data_dir, "EUR_eQTLs_within_context_for_selected_genes.csv"), index=False)
    
    YRI_eQTLs_within_context_for_selected_genes = gene_perf.merge(YRI_all_eQTLs, left_on="gene", right_on="our_gene_name", how="inner")
    YRI_eQTLs_within_context_for_selected_genes = YRI_eQTLs_within_context_for_selected_genes[YRI_eQTLs_within_context_for_selected_genes.columns[8:]]
    YRI_eQTLs_within_context_for_selected_genes.to_csv(os.path.join(data_dir, "YRI_eQTLs_within_context_for_selected_genes.csv"), index=False)

EUR_eQTLs_within_context_for_selected_genes = pd.read_csv(os.path.join(data_dir, "EUR_eQTLs_within_context_for_selected_genes.csv"))
YRI_eQTLs_within_context_for_selected_genes = pd.read_csv(os.path.join(data_dir, "YRI_eQTLs_within_context_for_selected_genes.csv"))

top_EUR_eQTL_for_every_gene = EUR_eQTLs_within_context_for_selected_genes.groupby("our_gene_name").head(1).reset_index(drop=True)
top_YRI_eQTL_for_every_gene = YRI_eQTLs_within_context_for_selected_genes.groupby("our_gene_name").head(1).reset_index(drop=True)

# %%
top_eQTL_AFs = []
for i in tqdm(range(len(top_EUR_eQTL_for_every_gene))):
    row = top_EUR_eQTL_for_every_gene.iloc[i]
    af = float(row["INFO"].split(";EUR_AF=")[-1].split(";")[0])
    af = min(af, 1 - af)
    top_eQTL_AFs.append(af)

top_EUR_eQTL_for_every_gene["EUR_AF"] = top_eQTL_AFs
# Out:
# 100%|██████████| 383/383 [00:00<00:00, 14909.45it/s]

# %% [markdown]
# # Random split genes analyses

# %%
random_split_gene_perf = gene_perf[gene_perf["gene_class"] == "random_split"].copy().reset_index(drop=True)

# %% [markdown]
# ## Performance vs. PrediXcan performance

# %%
spr = spearmanr(random_split_gene_perf["predixcan_Pearson"], 
                random_split_gene_perf["Mean Pearson Correlation"])[0]
pr = pearsonr(random_split_gene_perf["predixcan_Pearson"], 
              random_split_gene_perf["Mean Pearson Correlation"])[0]

sns.regplot(data=random_split_gene_perf, 
            x="predixcan_Pearson", 
            y="Mean Pearson Correlation")
plt.xlabel("PrediXcan Pearson Correlation")
plt.title(f"Relationship between fine-tuned model performance \nand PrediXcan performance\n(Spearman Correlation = {spr.round(3)})")
plt.show()

# %% [markdown]
# ## Performance vs. distance of strongest eQTL within context window to TSS

# %%
EUR_top_eQTLs_path = os.path.join(geuvadis_eQTL_dir, "EUR373.gene.cis.FDR5.best.rs137.txt.gz")
YRI_top_eQTLs_path = os.path.join(geuvadis_eQTL_dir, "YRI89.gene.cis.FDR5.best.rs137.txt.gz")

EUR_top_eQTLs = pd.read_csv(EUR_top_eQTLs_path, sep="\t", names=["SNP_ID", "ID", "GENE_ID", "PROBE_ID", 
                                                                 "CHR_SNP", "CHR_GENE", "SNPpos", "TSSpos", 
                                                                 "Absolute_Distance_from_TSS", "rvalue", "pvalue", "log10pvalue"])
YRI_top_eQTLs = pd.read_csv(YRI_top_eQTLs_path, sep="\t", names=["SNP_ID", "ID", "GENE_ID", "PROBE_ID", 
                                                                 "CHR_SNP", "CHR_GENE", "SNPpos", "TSSpos", 
                                                                 "Absolute_Distance_from_TSS", "rvalue", "pvalue", "log10pvalue"])

GEUVADIS_COUNTS = pd.read_csv(GEUVADIS_COUNTS_PATH)

# %%
top_EUR_eQTL_for_every_gene.columns
# Out:
# Index(['SNP_ID', 'ID', 'GENE_ID', 'PROBE_ID', 'CHR_SNP', 'CHR_GENE', 'SNPpos',
#        'TSSpos', 'distance', 'rvalue', 'pvalue', 'log10pvalue', 'abs_rvalue',
#        'stable_id', 'dbSNP_id', 'geuvadis_id', '#CHROM', 'POS', 'REF', 'ALT',
#        'INFO', 'our_gene_name', 'EUR_AF'],
#       dtype='object')

# %%
# random_split_gene_perf = random_split_gene_perf.merge(GEUVADIS_COUNTS[["our_gene_name", "top_EUR_eqtl_rsid", "top_YRI_eqtl_rsid", "top_EUR_eqtl_distance", "top_YRI_eqtl_distance"]], 
#                                                       left_on="gene", right_on="our_gene_name", how="inner").drop("our_gene_name", axis=1)
random_split_gene_perf = random_split_gene_perf.merge(top_EUR_eQTL_for_every_gene[["our_gene_name", "abs_rvalue", "pvalue", "log10pvalue", 'distance', '#CHROM', 'POS', 'REF', 'ALT', "EUR_AF"]], 
                                                      left_on="gene", right_on="our_gene_name", how="inner").drop("our_gene_name", axis=1)

random_split_gene_perf
# Out:
#        gene    gene_class  baseline_Pearson  predixcan_Pearson  \
# 0     znf83  random_split         -0.003408           0.411355
# 1    eftud2  random_split         -0.028312           0.392380
# 2    tspan4  random_split          0.187495           0.359469
# 3     nucb1  random_split          0.424650           0.372653
# 4     calm3  random_split         -0.025574           0.176973
# ..      ...           ...               ...                ...
# 155    mri1  random_split         -0.018817           0.513269
# 156   rdh13  random_split         -0.115446           0.275324
# 157   cdc37  random_split          0.214828           0.258199
# 158   fcrl3  random_split          0.391687           0.438667
# 159  p2ry11  random_split         -0.070466           0.316310
#
#      finetuned_Pearson_regression_data_seed_42_lr_0.0001_wd_0.001_rcprob_0.5_rsmax_3  \
# 0                                             0.359325
# 1                                             0.345252
# 2                                             0.258073
# 3                                             0.423714
# 4                                             0.122829
# ..                                                 ...
# 155                                           0.507127
# 156                                           0.290581
# 157                                           0.035548
# 158                                           0.382754
# 159                                           0.131997
#
#      finetuned_Pearson_regression_data_seed_97_lr_0.0001_wd_0.001_rcprob_0.5_rsmax_3  \
# 0                                             0.438791
# 1                                             0.406891
# 2                                             0.320718
# 3                                             0.320159
# 4                                             0.112955
# ..                                                 ...
# 155                                           0.497753
# 156                                           0.190437
# 157                                           0.249744
# 158                                           0.411078
# 159                                           0.325801
#
#      finetuned_Pearson_regression_data_seed_7_lr_0.0001_wd_0.001_rcprob_0.5_rsmax_3  \
# 0                                             0.335123
# 1                                             0.377886
# 2                                             0.341329
# 3                                             0.376667
# 4                                             0.042417
# ..                                                 ...
# 155                                           0.413111
# 156                                           0.219787
# 157                                           0.228735
# 158                                           0.417283
# 159                                           0.292171
#
#      Mean Pearson Correlation  abs_rvalue        pvalue  log10pvalue  \
# 0                    0.283310    0.350876  3.071768e-12    11.512612
# 1                    0.282507    0.268721  1.374719e-07     6.861786
# 2                    0.230030    0.239146  3.006855e-06     5.521888
# 3                    0.280135    0.238053  3.345370e-06     5.475556
# 4                    0.069550    0.272128  9.398158e-08     7.026957
# ..                        ...         ...           ...          ...
# 155                  0.354498    0.513628  1.849813e-26    25.732872
# 156                  0.175201    0.357029  1.200900e-12    11.920493
# 157                  0.128507    0.236770  3.789474e-06     5.421421
# 158                  0.302779    0.356370  1.329187e-12    11.876414
# 159                  0.187492    0.249685  1.046359e-06     5.980319
#
#      distance  #CHROM        POS    REF ALT  EUR_AF
# 0     21962.0      19   53171779      G   T    0.11
# 1     13347.0      17   42990340      C   T    0.37
# 2      5146.5      11     837661     GT   G    0.40
# 3      1248.0      19   49402059      C   A    0.28
# 4      3158.0      19   47101408      G   A    0.23
# ..        ...     ...        ...    ...  ..     ...
# 155    2771.5      19   13872565     TC   T    0.41
# 156    6511.0      19   55574403      C   G    0.16
# 157    7351.0      19   10521620  ATTAT   A    0.28
# 158    1782.0       1  157668993      C   T    0.47
# 159    6884.0      19   10229098      T  TG    0.47
#
# [160 rows x 17 columns]

# %%
# spr = spearmanr(random_split_gene_perf["top_EUR_eqtl_distance"], 
#                 random_split_gene_perf["Mean Pearson Correlation"])[0]
# pr = pearsonr(random_split_gene_perf["top_EUR_eqtl_distance"], 
#               random_split_gene_perf["Mean Pearson Correlation"])[0]

spr = spearmanr(random_split_gene_perf["distance"], 
                random_split_gene_perf["Mean Pearson Correlation"])[0]
pr = pearsonr(random_split_gene_perf["distance"], 
              random_split_gene_perf["Mean Pearson Correlation"])[0]

sns.regplot(data=random_split_gene_perf, 
            x="distance", 
            y="Mean Pearson Correlation")
plt.xlabel("Absolute distance of top EUR eQTL \nwithin context window (24.5kb) to TSS")
plt.title(f"Relationship between fine-tuned model performance \nand the distance of top eQTL to the TSS\n(Spearman Correlation = {spr.round(3)})")
plt.show()

# %% [markdown]
# ## Performance vs. log10p-val of strongest eQTL within context window

# %%
spr = spearmanr(random_split_gene_perf["log10pvalue"], 
                random_split_gene_perf["Mean Pearson Correlation"])[0]
pr = pearsonr(random_split_gene_perf["log10pvalue"], 
              random_split_gene_perf["Mean Pearson Correlation"])[0]

sns.regplot(data=random_split_gene_perf, 
            x="log10pvalue", 
            y="Mean Pearson Correlation")
plt.xlabel("-log10(p-value) of top EUR eQTL \nwithin context window (24.5kb)")
plt.title(f"Relationship between fine-tuned model performance \nand the p-value of top EUR eQTL within context window\n(Spearman Correlation = {spr.round(3)})")
plt.show()

# %% [markdown]
# ## Performance vs. EUR allele frequency of strongest eQTL within context window

# %%
spr = spearmanr(random_split_gene_perf["EUR_AF"], 
                random_split_gene_perf["Mean Pearson Correlation"])[0]
pr = pearsonr(random_split_gene_perf["EUR_AF"], 
              random_split_gene_perf["Mean Pearson Correlation"])[0]

sns.regplot(data=random_split_gene_perf, 
            x="EUR_AF", 
            y="Mean Pearson Correlation")
plt.xlabel("EUR minor allele frequency of top EUR eQTL \nwithin context window (24.5kb)")
plt.title(f"Relationship between fine-tuned model performance \nand the EUR minor AF of top EUR eQTL within context window\n(Spearman Correlation = {spr.round(3)})")
plt.show()

# %%
spr = spearmanr(random_split_gene_perf["EUR_AF"], 
                random_split_gene_perf["abs_rvalue"])[0]
pr = pearsonr(random_split_gene_perf["EUR_AF"], 
              random_split_gene_perf["abs_rvalue"])[0]

sns.regplot(data=random_split_gene_perf, 
            x="EUR_AF", 
            y="abs_rvalue")
plt.xlabel("EUR minor allele frequency of top EUR eQTL \nwithin context window (24.5kb)")
plt.title(f"(Spearman Correlation = {spr.round(3)})")
plt.show()

# %% [markdown]
# ## Performance vs. percentage of variants observed during training

# %%
random_split_gene_perf = random_split_gene_perf.merge(gene_variant_stats[["gene"] + gene_variant_stats.columns[-5:].tolist()], on="gene", how="inner")
random_split_gene_perf
# Out:
#        gene    gene_class  baseline_Pearson  predixcan_Pearson  \
# 0     znf83  random_split         -0.002427           0.343012
# 1    eftud2  random_split         -0.031810           0.382342
# 2    tspan4  random_split          0.187472           0.314566
# 3     nucb1  random_split          0.424683           0.172031
# 4     calm3  random_split         -0.027166           0.153913
# ..      ...           ...               ...                ...
# 155    mri1  random_split         -0.018565           0.498632
# 156   rdh13  random_split         -0.114664           0.291643
# 157   cdc37  random_split          0.225859           0.250160
# 158   fcrl3  random_split          0.391737           0.436433
# 159  p2ry11  random_split         -0.072132           0.317645
#
#      finetuned_Pearson_regression_data_seed_42_lr_0.0001_wd_0.001_rcprob_0.5_rsmax_3  \
# 0                                             0.359325
# 1                                             0.345252
# 2                                             0.258073
# 3                                             0.423714
# 4                                             0.122829
# ..                                                 ...
# 155                                           0.507127
# 156                                           0.290581
# 157                                           0.035548
# 158                                           0.382754
# 159                                           0.131997
#
#      finetuned_Pearson_regression_data_seed_97_lr_0.0001_wd_0.001_rcprob_0.5_rsmax_3  \
# 0                                             0.438791
# 1                                             0.406891
# 2                                             0.320718
# 3                                             0.320159
# 4                                             0.112955
# ..                                                 ...
# 155                                           0.497753
# 156                                           0.190437
# 157                                           0.249744
# 158                                           0.411078
# 159                                           0.325801
#
#      finetuned_Pearson_regression_data_seed_7_lr_0.0001_wd_0.001_rcprob_0.5_rsmax_3  \
# 0                                             0.335123
# 1                                             0.377886
# 2                                             0.341329
# 3                                             0.376667
# 4                                             0.042417
# ..                                                 ...
# 155                                           0.413111
# 156                                           0.219787
# 157                                           0.228735
# 158                                           0.417283
# 159                                           0.292171
#
#      Mean Pearson Correlation  abs_rvalue  log10pvalue  distance  #CHROM  \
# 0                    0.377746    0.350876    11.512612   21962.0      19
# 1                    0.376677    0.268721     6.861786   13347.0      17
# 2                    0.306707    0.239146     5.521888    5146.5      11
# 3                    0.373514    0.238053     5.475556    1248.0      19
# 4                    0.092734    0.272128     7.026957    3158.0      19
# ..                        ...         ...          ...       ...     ...
# 155                  0.472664    0.513628    25.732872    2771.5      19
# 156                  0.233602    0.357029    11.920493    6511.0      19
# 157                  0.171342    0.236770     5.421421    7351.0      19
# 158                  0.403705    0.356370    11.876414    1782.0       1
# 159                  0.249990    0.249685     5.980319    6884.0      19
#
#            POS    REF ALT  Percent of all variants seen during training  \
# 0     53171779      G   T                                     98.021309
# 1     42990340      C   T                                     96.728972
# 2       837661     GT   G                                     94.072658
# 3     49402059      C   A                                     96.153846
# 4     47101408      G   A                                     94.484412
# ..         ...    ...  ..                                           ...
# 155   13872565     TC   T                                     96.000000
# 156   55574403      C   G                                     92.857143
# 157   10521620  ATTAT   A                                     94.041451
# 158  157668993      C   T                                     91.689008
# 159   10229098      T  TG                                     95.000000
#
#      Num variants seen during training  \
# 0                                  644
# 1                                  414
# 2                                  492
# 3                                  525
# 4                                  394
# ..                                 ...
# 155                                552
# 156                                624
# 157                                363
# 158                                342
# 159                                399
#
#      Percent of all variants only seen during testing  \
# 0                                            1.369863
# 1                                            2.570093
# 2                                            5.162524
# 3                                            3.296703
# 4                                            5.035971
# ..                                                ...
# 155                                          1.565217
# 156                                          6.101190
# 157                                          4.145078
# 158                                          5.898123
# 159                                          3.095238
#
#      Num variants only seen during testing  Num variants
# 0                                        9           657
# 1                                       11           428
# 2                                       27           523
# 3                                       18           546
# 4                                       21           417
# ..                                     ...           ...
# 155                                      9           575
# 156                                     41           672
# 157                                     16           386
# 158                                     22           373
# 159                                     13           420
#
# [160 rows x 20 columns]

# %%
spr = spearmanr(random_split_gene_perf["Percent of all variants seen during training"], 
                random_split_gene_perf["Mean Pearson Correlation"])[0]
pr = pearsonr(random_split_gene_perf["Percent of all variants seen during training"], 
              random_split_gene_perf["Mean Pearson Correlation"])[0]

sns.regplot(data=random_split_gene_perf, 
            x="Percent of all variants seen during training", 
            y="Mean Pearson Correlation")
plt.title(f"Relationship between fine-tuned model performance \nand the proportion of all variants seen during training\n(Spearman Correlation = {spr.round(3)})")
plt.show()

# %%
spr = spearmanr(random_split_gene_perf["Num variants seen during training"], 
                random_split_gene_perf["Mean Pearson Correlation"])[0]
pr = pearsonr(random_split_gene_perf["Num variants seen during training"], 
              random_split_gene_perf["Mean Pearson Correlation"])[0]

sns.regplot(data=random_split_gene_perf, 
            x="Num variants seen during training", 
            y="Mean Pearson Correlation", robust=True)
plt.xlabel("Number of variants seen during training (log scale)")
plt.title(f"Relationship between fine-tuned model performance \nand the number of variants seen during training\n(Spearman Correlation = {spr.round(3)})")
plt.xscale("log")
plt.show()

# %% [markdown]
# # Population split genes analyses

# %%
yri_split_gene_perf = gene_perf[gene_perf["gene_class"] == "yri_split"].copy().reset_index(drop=True)

# %% [markdown]
# ## Performance vs. PrediXcan performance

# %%
spr = spearmanr(yri_split_gene_perf["predixcan_Pearson"], 
                yri_split_gene_perf["Mean Pearson Correlation"])[0]
pr = pearsonr(yri_split_gene_perf["predixcan_Pearson"], 
              yri_split_gene_perf["Mean Pearson Correlation"])[0]

sns.regplot(data=yri_split_gene_perf, 
            x="predixcan_Pearson", 
            y="Mean Pearson Correlation")
plt.xlabel("PrediXcan Pearson Correlation")
plt.title(f"Relationship between fine-tuned model performance \nand PrediXcan performance\n(Pearson Correlation = {pr.round(3)})")
plt.show()

# %% [markdown]
# ## Difference in fine-tuned Enformer and PrediXcan performance vs. baseline Enformer performance

# %%
yri_split_gene_perf["Fine-tuned Enformer - PrediXcan"] = yri_split_gene_perf["Mean Pearson Correlation"] - yri_split_gene_perf["predixcan_Pearson"]
yri_split_gene_perf["Fine-tuned Enformer - PrediXcan"] = yri_split_gene_perf["Mean Pearson Correlation"] - yri_split_gene_perf["predixcan_Pearson"]
yri_split_gene_perf["|baseline_Pearson|"] = np.abs(yri_split_gene_perf["baseline_Pearson"])

spr = spearmanr(yri_split_gene_perf["baseline_Pearson"], 
                yri_split_gene_perf["Fine-tuned Enformer - PrediXcan"])[0]
pr = pearsonr(yri_split_gene_perf["baseline_Pearson"], 
                yri_split_gene_perf["Fine-tuned Enformer - PrediXcan"])[0]

sns.regplot(data=yri_split_gene_perf, 
            x="baseline_Pearson", 
            y="Fine-tuned Enformer - PrediXcan")
# plt.xlabel("PrediXcan Pearson Correlation")
plt.title(f"Relationship between \nfine-tuned model performance - PrediXcan performance\nand baseline Enformer performance\n(Pearson Correlation = {pr.round(3)})")
plt.show()

# %% [markdown]
# ## Performance vs. whether EUR top eQTL == YRI top eQTL

# %%
yri_split_gene_perf = yri_split_gene_perf.merge(GEUVADIS_COUNTS[["our_gene_name", "top_EUR_eqtl_rsid", "top_YRI_eqtl_rsid", "top_EUR_eqtl_distance", "top_YRI_eqtl_distance"]], 
                                                      left_on="gene", right_on="our_gene_name", how="inner").drop("our_gene_name", axis=1)
yri_split_gene_perf
# Out:
#          gene gene_class  baseline_Pearson  predixcan_Pearson  \
# 0      borcs7  yri_split          0.014520           0.441777
# 1        rtn4  yri_split         -0.190915          -0.004560
# 2      borcs5  yri_split          0.003120          -0.015952
# 3       epdr1  yri_split         -0.031474          -0.025755
# 4       smug1  yri_split          0.037427           0.154789
# ..        ...        ...               ...                ...
# 195  klhl7-dt  yri_split         -0.005762           0.732443
# 196     fbxl5  yri_split          0.024831           0.001551
# 197    papss1  yri_split         -0.058410           0.193478
# 198     hyal4  yri_split          0.090285           0.025782
# 199    csrnp1  yri_split          0.011377           0.040066
#
#      finetuned_Pearson_regression_data_seed_42_lr_0.0001_wd_0.001_rcprob_0.5_rsmax_3  \
# 0                                             0.382340
# 1                                             0.134631
# 2                                             0.127085
# 3                                            -0.102745
# 4                                             0.143848
# ..                                                 ...
# 195                                           0.746198
# 196                                           0.015846
# 197                                           0.224284
# 198                                          -0.062955
# 199                                           0.111060
#
#      finetuned_Pearson_regression_data_seed_97_lr_0.0001_wd_0.001_rcprob_0.5_rsmax_3  \
# 0                                             0.438982
# 1                                             0.087783
# 2                                             0.105851
# 3                                            -0.096989
# 4                                             0.067110
# ..                                                 ...
# 195                                           0.719341
# 196                                           0.069256
# 197                                           0.120820
# 198                                          -0.071133
# 199                                           0.109526
#
#      finetuned_Pearson_regression_data_seed_7_lr_0.0001_wd_0.001_rcprob_0.5_rsmax_3  \
# 0                                             0.370680
# 1                                             0.189967
# 2                                             0.014372
# 3                                            -0.103741
# 4                                             0.120817
# ..                                                 ...
# 195                                           0.723480
# 196                                           0.078318
# 197                                           0.220313
# 198                                          -0.035435
# 199                                           0.185508
#
#      Mean Pearson Correlation top_EUR_eqtl_rsid top_YRI_eqtl_rsid  \
# 0                    0.397334            rs9527               NaN
# 1                    0.137460         rs1822616               NaN
# 2                    0.082436       rs146170099               NaN
# 3                   -0.101158         rs7807193               NaN
# 4                    0.110591         rs2233921               NaN
# ..                        ...               ...               ...
# 195                  0.729673        rs10233039        rs28646184
# 196                  0.054473        rs35929560               NaN
# 197                  0.188472         rs2158180               NaN
# 198                 -0.056508        rs75614337               NaN
# 199                  0.135365         rs7623800               NaN
#
#      top_EUR_eqtl_distance  top_YRI_eqtl_distance
# 0                   9598.0                    NaN
# 1                  55879.0                    NaN
# 2                 107772.0                    NaN
# 3                 211227.0                    NaN
# 4                   6978.0                    NaN
# ..                     ...                    ...
# 195                 2209.0                 5727.0
# 196               221614.0                    NaN
# 197                 3071.0                    NaN
# 198               198537.0                    NaN
# 199                 5111.0                    NaN
#
# [200 rows x 12 columns]

# %%
yri_split_gene_perf["Top EUR eQTL is the same as the top YRI eQTL"] = yri_split_gene_perf["top_EUR_eqtl_rsid"] == yri_split_gene_perf["top_YRI_eqtl_rsid"]

# %%
sns.histplot(data=yri_split_gene_perf, 
            hue="Top EUR eQTL is the same as the top YRI eQTL", 
            x="Mean Pearson Correlation")
plt.title(f"Relationship between fine-tuned model performance \nand whether the top EUR eQTL is the same as the top YRI eQTL")
plt.show()

# %% [markdown]
# ## Performance vs. percentage of variants observed during training

# %%
yri_split_gene_perf = yri_split_gene_perf.merge(gene_variant_stats[["gene"] + gene_variant_stats.columns[-5:].tolist()], on="gene", how="inner")
yri_split_gene_perf
# Out:
#          gene gene_class  baseline_Pearson  predixcan_Pearson  \
# 0      borcs7  yri_split          0.014520           0.441777
# 1        rtn4  yri_split         -0.190915          -0.004560
# 2      borcs5  yri_split          0.003120          -0.015952
# 3       epdr1  yri_split         -0.031474          -0.025755
# 4       smug1  yri_split          0.037427           0.154789
# ..        ...        ...               ...                ...
# 195  klhl7-dt  yri_split         -0.005762           0.732443
# 196     fbxl5  yri_split          0.024831           0.001551
# 197    papss1  yri_split         -0.058410           0.193478
# 198     hyal4  yri_split          0.090285           0.025782
# 199    csrnp1  yri_split          0.011377           0.040066
#
#      finetuned_Pearson_regression_data_seed_42_lr_0.0001_wd_0.001_rcprob_0.5_rsmax_3  \
# 0                                             0.382340
# 1                                             0.134631
# 2                                             0.127085
# 3                                            -0.102745
# 4                                             0.143848
# ..                                                 ...
# 195                                           0.746198
# 196                                           0.015846
# 197                                           0.224284
# 198                                          -0.062955
# 199                                           0.111060
#
#      finetuned_Pearson_regression_data_seed_97_lr_0.0001_wd_0.001_rcprob_0.5_rsmax_3  \
# 0                                             0.438982
# 1                                             0.087783
# 2                                             0.105851
# 3                                            -0.096989
# 4                                             0.067110
# ..                                                 ...
# 195                                           0.719341
# 196                                           0.069256
# 197                                           0.120820
# 198                                          -0.071133
# 199                                           0.109526
#
#      finetuned_Pearson_regression_data_seed_7_lr_0.0001_wd_0.001_rcprob_0.5_rsmax_3  \
# 0                                             0.370680
# 1                                             0.189967
# 2                                             0.014372
# 3                                            -0.103741
# 4                                             0.120817
# ..                                                 ...
# 195                                           0.723480
# 196                                           0.078318
# 197                                           0.220313
# 198                                          -0.035435
# 199                                           0.185508
#
#      Mean Pearson Correlation top_EUR_eqtl_rsid top_YRI_eqtl_rsid  \
# 0                    0.397334            rs9527               NaN
# 1                    0.137460         rs1822616               NaN
# 2                    0.082436       rs146170099               NaN
# 3                   -0.101158         rs7807193               NaN
# 4                    0.110591         rs2233921               NaN
# ..                        ...               ...               ...
# 195                  0.729673        rs10233039        rs28646184
# 196                  0.054473        rs35929560               NaN
# 197                  0.188472         rs2158180               NaN
# 198                 -0.056508        rs75614337               NaN
# 199                  0.135365         rs7623800               NaN
#
#      top_EUR_eqtl_distance  top_YRI_eqtl_distance  \
# 0                   9598.0                    NaN
# 1                  55879.0                    NaN
# 2                 107772.0                    NaN
# 3                 211227.0                    NaN
# 4                   6978.0                    NaN
# ..                     ...                    ...
# 195                 2209.0                 5727.0
# 196               221614.0                    NaN
# 197                 3071.0                    NaN
# 198               198537.0                    NaN
# 199                 5111.0                    NaN
#
#      Top EUR eQTL is the same as the top YRI eQTL  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
# ..                                            ...
# 195                                         False
# 196                                         False
# 197                                         False
# 198                                         False
# 199                                         False
#
#      Percent of all variants seen during training  \
# 0                                       76.676385
# 1                                       67.105263
# 2                                       65.868263
# 3                                       60.051546
# 4                                       57.471264
# ..                                            ...
# 195                                     62.623762
# 196                                     65.439093
# 197                                     53.110048
# 198                                     63.302752
# 199                                     64.676617
#
#      Num variants seen during training  \
# 0                                  263
# 1                                  357
# 2                                  330
# 3                                  233
# 4                                  200
# ..                                 ...
# 195                                253
# 196                                231
# 197                                222
# 198                                207
# 199                                260
#
#      Percent of all variants only seen during testing  \
# 0                                           23.323615
# 1                                           31.390977
# 2                                           33.333333
# 3                                           35.309278
# 4                                           41.379310
# ..                                                ...
# 195                                         36.386139
# 196                                         32.861190
# 197                                         46.172249
# 198                                         36.085627
# 199                                         34.577114
#
#      Num variants only seen during testing  Num variants
# 0                                       80           343
# 1                                      167           532
# 2                                      167           501
# 3                                      137           388
# 4                                      144           348
# ..                                     ...           ...
# 195                                    147           404
# 196                                    116           353
# 197                                    193           418
# 198                                    118           327
# 199                                    139           402
#
# [200 rows x 18 columns]

# %%
spr = spearmanr(yri_split_gene_perf["Percent of all variants seen during training"], 
                yri_split_gene_perf["Mean Pearson Correlation"])[0]
pr = pearsonr(yri_split_gene_perf["Percent of all variants seen during training"], 
              yri_split_gene_perf["Mean Pearson Correlation"])[0]

sns.regplot(data=yri_split_gene_perf, 
            x="Percent of all variants seen during training", 
            y="Mean Pearson Correlation")
plt.title(f"Relationship between fine-tuned model performance \nand the proportion of all variants seen during training\n(Pearson Correlation = {pr.round(3)})")
plt.show()

# %%
spr = spearmanr(yri_split_gene_perf["Num variants seen during training"], 
                yri_split_gene_perf["Mean Pearson Correlation"])[0]
pr = pearsonr(yri_split_gene_perf["Num variants seen during training"], 
              yri_split_gene_perf["Mean Pearson Correlation"])[0]

sns.regplot(data=yri_split_gene_perf, 
            x="Num variants seen during training", 
            y="Mean Pearson Correlation")
plt.xlabel("Number of variants seen during training")
plt.title(f"Relationship between fine-tuned model performance \nand the number of variants seen during training\n(Spearman Correlation = {spr.round(3)})")
# plt.xscale("log")
plt.show()

# %% [markdown]
# ## Performance vs. percentage of variants observed only during testing

# %%
spr = spearmanr(yri_split_gene_perf["Percent of all variants only seen during testing"], 
                yri_split_gene_perf["Mean Pearson Correlation"])[0]
pr = pearsonr(yri_split_gene_perf["Percent of all variants only seen during testing"], 
              yri_split_gene_perf["Mean Pearson Correlation"])[0]

sns.regplot(data=yri_split_gene_perf, 
            x="Percent of all variants only seen during testing", 
            y="Mean Pearson Correlation")
plt.title(f"Relationship between fine-tuned model performance \nand the proportion of all variants only seen during testing\n(Pearson Correlation = {pr.round(3)})")
plt.show()

# %%
spr = spearmanr(yri_split_gene_perf["Num variants only seen during testing"], 
                yri_split_gene_perf["Mean Pearson Correlation"])[0]
pr = pearsonr(yri_split_gene_perf["Num variants only seen during testing"], 
              yri_split_gene_perf["Mean Pearson Correlation"])[0]

sns.regplot(data=yri_split_gene_perf, 
            x="Num variants only seen during testing", 
            y="Mean Pearson Correlation")
plt.xlabel("Number of variants only seen during testing")
plt.title(f"Relationship between fine-tuned model performance \nand the number of variants only seen during testing\n(Pearson Correlation = {pr.round(3)})")
# plt.xscale("log")
plt.show()

# %% [markdown]
# ## Can fine-tuned model order populations by their expression even if it can’t order individuals within populations?

# %% [markdown]
# # Unseen genes analyses

# %%
unseen_split_gene_perf = gene_perf[gene_perf["gene_class"] == "unseen"].copy().reset_index(drop=True)

# %% [markdown]
# ## Performance vs. Baseline performance

# %%
spr = spearmanr(unseen_split_gene_perf["baseline_Pearson"], 
                unseen_split_gene_perf["Mean Pearson Correlation"])[0]
pr = pearsonr(unseen_split_gene_perf["baseline_Pearson"], 
              unseen_split_gene_perf["Mean Pearson Correlation"])[0]

sns.regplot(data=unseen_split_gene_perf, 
            x="baseline_Pearson", 
            y="Mean Pearson Correlation")
plt.xlabel("Baseline Enformer Pearson Correlation")
plt.title(f"Relationship between fine-tuned model performance \nand baseline Enformer performance\n(Pearson Correlation = {pr.round(3)})")
plt.show()
